# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import numpy as np

w_6cl_76acc_conicity = np.array([[ 0.4939586 ,  0.24907774,  0.11841054,  0.27636716,  0.21386734],
       [-0.12210199,  0.2631342 ,  0.40729067,  0.10686614,  0.23702331],
       [ 0.0399085 ,  0.00714708,  0.17319691,  0.171847  ,  0.00353743],
       [-0.13240775, -0.12906815, -0.15348402, -0.03282084, -0.17010587],
       [ 0.14703462, -0.12421241,  0.07568351, -0.11122461, -0.180013  ]],
      dtype= np.float32)

w_5cl_75_acc_conicity = np.array([[-0.08284566,  0.35191852,  0.5211162 ,  0.01450577,  0.15423156],
       [ 0.3080385 ,  0.21253692, -0.08387452,  0.30840966,  0.09994161],
       [-0.09241749,  0.08388491,  0.35235128,  0.17544062,  0.0802008 ],
       [ 0.01893541,  0.375397  , -0.28716207, -0.05745003,  0.01865164],
       [ 0.16883385, -0.08154894, -0.03846832, -0.33658963, -0.18546623]],
      dtype= np.float32)

w_4cl_66acc_conicity = np.array([[ 0.5274173 , -0.34561956, -0.02199763, -0.35332552,  0.69528073],
       [ 0.24694699,  0.14660335,  0.34531042, -0.39689893,  0.4549166 ],
       [ 0.07341592,  0.32967108,  0.10416995, -0.3066177 ,  0.07185814],
       [-0.5700954 , -0.2822512 , -0.2828022 , -0.02243232, -0.10925791],
       [ 0.08985886,  0.2283992 ,  0.23388003,  0.39577526,  0.05197057]],
      dtype = np.float32)

w_3cl_62acc_conicity = np.array([[-0.3158658 , -0.10946564, -0.253507  , -0.11189008, -0.10347716],
       [-0.38550797, -0.04193256, -0.1304727 ,  0.01223115, -0.33426762],
       [ 0.2573835 ,  0.05068673,  0.00682069, -0.16315444, -0.1274074 ],
       [ 0.0409035 ,  0.04889183, -0.0483536 ,  0.11260844, -0.02234463],
       [-0.1213106 ,  0.11426189, -0.11243778, -0.11235334,  0.27071413]],
      dtype= np.float32)

w_2cl_58acc_conicity = np.array([[-3.76470059e-01, -1.88808620e-01, -2.59847164e-01,
         3.82273436e-01,  2.65789181e-01],
       [-4.99323577e-01,  4.07341532e-02, -2.75108725e-01,
         3.67254466e-01, -1.14894850e-04],
       [-2.32826665e-01,  7.81243294e-02,  2.86420155e-02,
         1.40242055e-01,  7.45923072e-02],
       [-1.53596178e-01, -6.73958659e-02, -1.41027644e-01,
        -1.11929156e-01,  9.46439654e-02],
       [-1.50039634e-02,  1.20813690e-01, -9.37035531e-02,
         8.60411525e-02, -1.18597932e-02]], dtype=np.float32)

conicity_images = [w_2cl_58acc_conicity, w_3cl_62acc_conicity, w_4cl_66acc_conicity, w_5cl_75_acc_conicity, w_6cl_76acc_conicity]
img_tit_coni = ['2 classifiers, 58%', '3 classifiers, 62%', '4 classifiers, 66%', '5 classifiers, 75%', '6 classifiers, 76%']

# %%
w_6cl_69acc_stdot = np.array([[-0.3303155 , -0.31719643, -0.38582838, -0.18001084, -0.34796658],
       [-0.32499772,  0.22450213, -0.10045109, -0.22714905, -0.05735724],
       [-0.05934272,  0.18477033, -0.33529663,  0.29547253, -0.04437399],
       [ 0.34797558, -0.2955861 , -0.30031872, -0.06767228,  0.01137508],
       [-0.01731959,  0.02533676, -0.08968946,  0.3112559 , -0.36443388]],
      dtype=np.float32)

w_5cl_67acc_stdot = np.array([[ 0.23909128,  0.14694525,  0.38715288,  0.36394092, -0.00903775],
       [ 0.44156477, -0.18334563,  0.06986351,  0.3691985 ,  0.00873555],
       [ 0.38013104, -0.48792946, -0.00390682,  0.08048092,  0.48050323],
       [-0.26454142,  0.1783669 , -0.3159348 , -0.09601886, -0.0760524 ],
       [-0.3670935 ,  0.0568953 , -0.5044818 , -0.3299471 , -0.1366969 ]],
      dtype=np.float32)

w_4cl_68acc_stdot = np.array([[ 0.02510977,  0.25922188,  0.1250386 , -0.31045455,  0.14281803],
       [ 0.2596918 , -0.04006084, -0.04360323,  0.32148564,  0.31675172],
       [ 0.21638028,  0.14712423,  0.165173  , -0.20570408,  0.30036408],
       [ 0.21126315,  0.16818927,  0.15116139, -0.12265395, -0.00420022],
       [ 0.22550625, -0.04228699,  0.16692506, -0.4066828 ,  0.03249547]],
      dtype=np.float32)

w_3cl_62acc_stdot = np.array([[-0.2166724 , -0.29284367, -0.07575222,  0.38183555, -0.01319309],
       [-0.24469091,  0.25012675, -0.15881419,  0.5216459 ,  0.16117118],
       [-0.18086867,  0.02391964, -0.05913332, -0.21997802,  0.12419992],
       [ 0.08567528, -0.19207412,  0.04680514, -0.28602242,  0.17396006],
       [ 0.07981148, -0.11430953, -0.06517173, -0.09737429,  0.03968184]],
      dtype=np.float32)

w_2cl_65acc_stdot = np.array([[-0.62450683,  0.03476851,  0.27311915, -0.26352236, -0.30253   ],
       [-0.34738496, -0.1344009 , -0.24825297,  0.0805316 , -0.48849952],
       [-0.11152058,  0.20325983, -0.09497321, -0.10849693, -0.06455769],
       [-0.01015961,  0.24756967, -0.18040098,  0.02425907,  0.08392727],
       [-0.23925623,  0.24711649,  0.0358836 ,  0.1857621 , -0.05744134]],
      dtype=np.float32)

stdot_images = [w_2cl_65acc_stdot, w_3cl_62acc_stdot, w_4cl_68acc_stdot, w_5cl_67acc_stdot, w_6cl_69acc_stdot]
img_tit_stdot = ['2 classifiers, 65%', '3 classifiers, 62%', '4 classifiers, 68%', '5 classifiers, 67%', '6 classifiers, 69%']

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(5, 1, figsize=(8, 15),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.2, wspace=0.1))
for i, ax in enumerate(axes.flat):
    ax.imshow(conicity_images[i].reshape(5, 5))
    fig.colorbar(ax.imshow(conicity_images[i].reshape(5, 5)), ax = ax)
    ax.set_title(img_tit_coni[i])

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(5, 1, figsize=(8, 15),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.2, wspace=0.1))
for i, ax in enumerate(axes.flat):
    ax.imshow(stdot_images[i].reshape(5, 5))
    fig.colorbar(ax.imshow(stdot_images[i].reshape(5, 5)), ax = ax)
    ax.set_title(img_tit_stdot[i])

# %% [markdown]
# ### The Upper triangular plots (conicity loss)

# %%
# 2 classifiers
# lambda = 100 (optimal)
n2_63 = np.array([[ 0.3422667 ,  0.07637621, -0.02932019,  0.294983  ,  0.19854042],
       [-0.0174227 ,  0.04246153,  0.05162233,  0.12987262,  0.04111638],
       [ 0.06181799,  0.31653547, -0.19784257,  0.17148182, -0.01223312],
       [-0.14398186,  0.12518881,  0.23281868,  0.00179205, -0.3010304 ],
       [ 0.06832283, -0.09578811, -0.1724201 , -0.04663246,  0.02596386]],
      dtype=np.float32)

n2_60 = np.array([[-0.486766  , -0.10858987,  0.0415494 , -0.41964194, -0.28243172],
       [ 0.02458149, -0.06021434, -0.07324683, -0.18465596, -0.0588038 ],
       [-0.0887081 , -0.45008475,  0.28127757, -0.24391478,  0.0173475 ],
       [ 0.20470129, -0.17803554, -0.3313928 , -0.00266707,  0.42721227],
       [-0.09759516,  0.13581692,  0.24502021,  0.06538075, -0.03815313]],
      dtype=np.float32)

# lambda = 10
# n2_51 = np.array([[-0.097501  , -0.28669846, -0.07569546, -0.19884217, -0.14770758],
#        [-0.08061615, -0.2593956 , -0.00325378, -0.28041768, -0.35666755],
#        [ 0.0570148 ,  0.15525278,  0.1723955 ,  0.0135766 , -0.05436257],
#        [ 0.09584735, -0.06014361,  0.09488603,  0.04930868,  0.22987874],
#        [ 0.14329508,  0.08810233,  0.01996456, -0.06170708, -0.08788788]],
#       dtype=np.float32)

# n2_54 = np.array([[ 0.17351633,  0.49803677,  0.13164414,  0.34618244,  0.2641407 ],
#        [ 0.14063093,  0.4519282 ,  0.00500587,  0.49055293,  0.62452644],
#        [-0.10029363, -0.27273455, -0.30227   , -0.02405195,  0.09448341],
#        [-0.16873328,  0.10368521, -0.16736028, -0.08820582, -0.404632  ],
#        [-0.25177842, -0.15540367, -0.03562997,  0.10497437,  0.14920178]],
#       dtype=np.float32)

n2_62 = np.array([[ 0.4187876 ,  0.14655028, -0.21949425, -0.00915416, -0.02933958],
       [ 0.01781426,  0.4177144 ,  0.4587922 ,  0.4130238 ,  0.19247188],
       [ 0.14144629,  0.13292077,  0.31069952,  0.02355975,  0.14738327],
       [-0.12698995, -0.1777373 , -0.15201843,  0.34258842,  0.2561191 ],
       [-0.04095809, -0.01899501,  0.49066103,  0.27329695,  0.46812555]],
      dtype=np.float32)

n2_55 = np.array([[-0.26477706, -0.09294606,  0.13794002,  0.00490833,  0.01771438],
       [-0.01164909, -0.2636214 , -0.28942305, -0.26063332, -0.12196433],
       [-0.08968246, -0.08414845, -0.1960987 , -0.01526701, -0.09311779],
       [ 0.0795439 ,  0.11174049,  0.09553183, -0.21592817, -0.16159447],
       [ 0.02533056,  0.01160233, -0.30941162, -0.17210913, -0.2948845 ]],
      dtype=np.float32)

# lambda = 1000
n2_59 = np.array([[ 0.2189339 , -0.06638422, -0.2208685 , -0.19395593, -0.01292588],
       [ 0.01915542, -0.19644883, -0.12299937, -0.02926913, -0.03954706],
       [-0.00575986, -0.15972584,  0.00332641, -0.24913542,  0.18187624],
       [ 0.11703058, -0.03500981,  0.16326587, -0.09173114,  0.22331455],
       [-0.12351458, -0.00300038, -0.10348784,  0.03298965,  0.00033444]],
      dtype=np.float32)

n2_58 = np.array([[ 0.2189339 , -0.06638422, -0.2208685 , -0.19395593, -0.01292588],
       [ 0.01915542, -0.19644883, -0.12299937, -0.02926913, -0.03954706],
       [-0.00575986, -0.15972584,  0.00332641, -0.24913542,  0.18187624],
       [ 0.11703058, -0.03500981,  0.16326587, -0.09173114,  0.22331455],
       [-0.12351458, -0.00300038, -0.10348784,  0.03298965,  0.00033444]],
      dtype=np.float32)

# %%
# 3 classifiers

# lambda = 1000 (optimal)
n3_62 = np.array([[-0.33882815, -0.16112457,  0.02684269, -0.13096943, -0.2845624 ],
       [ 0.11690467,  0.23416469, -0.6045787 ,  0.13353795, -0.1776749 ],
       [-0.03940604, -0.31653512, -0.29645574, -0.44984213,  0.25008425],
       [-0.25254497, -0.09047455,  0.46695608, -0.17049757, -0.25298303],
       [ 0.16398184, -0.02669728, -0.47661588,  0.14221905, -0.1382397 ]],
      dtype=np.float32)

n3_60 = np.array([[ 0.36106193, -0.035808  ,  0.06920522,  0.34912726,  0.0352233 ],
       [-0.14979298,  0.12646121,  0.186966  , -0.23846896,  0.08509044],
       [ 0.16785735,  0.14216812, -0.05623063,  0.04216966, -0.2840167 ],
       [ 0.09425149,  0.03392097, -0.14905867, -0.05920184, -0.09271952],
       [-0.09171965,  0.3301881 ,  0.37421364, -0.0241005 ,  0.13532428]],
      dtype=np.float32)

n3_52 = np.array([[-0.16129252,  0.1647428 ,  0.00800267, -0.34542814,  0.22456275],
       [ 0.02651033, -0.34907216,  0.32400724,  0.18247229,  0.11158356],
       [-0.17915729,  0.11436485,  0.35525405,  0.36676198,  0.13357182],
       [ 0.12874165,  0.00483269, -0.28479344,  0.18916324,  0.33822712],
       [-0.08272317, -0.31540993,  0.00959124, -0.10650776, -0.0276025 ]],
      dtype=np.float32)

# lambda = 100
n3_61 = np.array([[ 0.31384757,  0.00649463, -0.32184112,  0.3513084 ,  0.30017877],
       [ 0.1667946 ,  0.16831902, -0.43330154, -0.1414646 ,  0.00917946],
       [ 0.29810548, -0.27014202,  0.08280266, -0.34946144,  0.31035212],
       [ 0.0306569 , -0.1529609 ,  0.19367899, -0.1816964 ,  0.10616739],
       [ 0.01981967, -0.16626999, -0.01314983,  0.13064614, -0.03018142]],
      dtype=np.float32)

n3_50 = np.array([[ 0.21080674, -0.17130932,  0.18487485, -0.22869858,  0.11751762],
       [-0.32073894,  0.01579105,  0.427848  ,  0.46076524,  0.7830876 ],
       [-0.35714126,  0.44196203,  0.07217674,  0.43757382, -0.21588905],
       [-0.47992414,  0.33243534, -0.46419862,  0.09977582,  0.11125612],
       [ 0.25702533, -0.00938415,  0.05384991,  0.03586288, -0.25784117]],
      dtype=np.float32)

n3_52_1 = np.array([[ 0.21080674, -0.17130932,  0.18487485, -0.22869858,  0.11751762],
       [-0.32073894,  0.01579105,  0.427848  ,  0.46076524,  0.7830876 ],
       [-0.35714126,  0.44196203,  0.07217674,  0.43757382, -0.21588905],
       [-0.47992414,  0.33243534, -0.46419862,  0.09977582,  0.11125612],
       [ 0.25702533, -0.00938415,  0.05384991,  0.03586288, -0.25784117]],
      dtype=np.float32)

#lambda = 10000
n3_52_2 = np.array([[ 0.18111295,  0.5674299 , -0.13143362,  0.16466986, -0.42764294],
       [-0.12215886,  0.20538396,  0.29792368, -0.1221827 , -0.00906917],
       [ 0.29353717, -0.27598736,  0.33159587,  0.4315624 ,  0.4627421 ],
       [-0.14411472, -0.29582283, -0.39738697, -0.4681385 ,  0.31504077],
       [ 0.09577483, -0.10285114,  0.01578281, -0.34648564,  0.12181384]],
      dtype=np.float32)

n3_51 = np.array([[-0.12718038, -0.088852  , -0.03373382, -0.30056295,  0.0306775 ],
       [ 0.01575713, -0.08513477,  0.02855948,  0.10574248,  0.1489037 ],
       [-0.31659424, -0.0173519 , -0.00883045, -0.00997748, -0.01199639],
       [ 0.25189412, -0.04806999,  0.25552964,  0.02452377, -0.17479101],
       [-0.11499555, -0.08048668, -0.07140581,  0.0457908 , -0.13189855]],
      dtype=np.float32)

n3_53 = np.array([[ 0.10031462, -0.439334  ,  0.2178673 ,  0.50554943,  0.4434273 ],
       [ 0.03030828, -0.09394614, -0.30849934,  0.01471646, -0.16010259],
       [ 0.23546375,  0.28948322, -0.31267518, -0.35258964, -0.40707046],
       [-0.30087438,  0.3413173 , -0.02416335,  0.39201772, -0.00866535],
       [ 0.08663367,  0.01116828,  0.166391  ,  0.24099119,  0.06574067]],
      dtype=np.float32)

# %%
# 4 classifiers

# lambda = 100 (optimal)
n4_55 = np.array([[ 0.33375394, -0.06231033,  0.45744336, -0.13232212,  0.17359367],
       [ 0.2318052 , -0.19609445,  0.07014725,  0.27425984,  0.17917939],
       [-0.27709544, -0.17940348, -0.09504271, -0.08447547,  0.42804667],
       [ 0.18182656, -0.1709615 , -0.17055994,  0.14472376,  0.15297082],
       [-0.11728658, -0.29472095,  0.33291242, -0.04245737, -0.18790753]],
      dtype=np.float32)


n4_74 = np.array([[-0.23486614, -0.0117695 ,  0.2787063 ,  0.10506836,  0.45599678],
       [ 0.36829448,  0.3349196 ,  0.21219428,  0.13796096, -0.01102992],
       [-0.07531641,  0.19058439,  0.42967936, -0.05102225, -0.4021365 ],
       [-0.19366509,  0.17576991, -0.30378297, -0.01124947, -0.180255  ],
       [-0.00489354,  0.13612963,  0.07927671,  0.03863645, -0.00481476]],
      dtype=np.float32)


n4_65 = np.array([[-0.03410936,  0.1548469 , -0.2953278 , -0.09996538, -0.09297091],
       [-0.3650142 ,  0.01634218, -0.23414557, -0.18907999, -0.07684725],
       [-0.00920663, -0.11069708, -0.0653392 ,  0.14039068,  0.18790683],
       [ 0.00082234,  0.12942259,  0.13394529, -0.09047467,  0.06608952],
       [ 0.06248198, -0.10664796, -0.03707307,  0.03659966,  0.03287686]],
      dtype=np.float32)

n4_53 = np.array([[-0.09138745, -0.18819587, -0.42194337,  0.08988377, -0.503876  ],
       [-0.10629398, -0.17529786,  0.03904766, -0.19275479, -0.05559704],
       [ 0.27273807,  0.10352997, -0.28680718, -0.07796246, -0.2830102 ],
       [-0.02279633, -0.22731194,  0.23539491,  0.05860834, -0.07909089],
       [-0.00438574,  0.27771774, -0.34300733, -0.02931154,  0.15440999]],
      dtype=np.float32)

# lambda = 1000
n4_50 = np.array([[-0.2907466 ,  0.31444636, -0.19473359, -0.10306545, -0.36440057],
       [ 0.00843905,  0.13330455, -0.00738498, -0.06171049, -0.17588173],
       [-0.2453819 ,  0.0997652 , -0.23203263,  0.20057084, -0.180024  ],
       [ 0.22642212, -0.21144193, -0.119424  ,  0.0252111 ,  0.06686494],
       [-0.12370763,  0.11799331, -0.13499105,  0.2917436 , -0.06665166]],
      dtype=np.float32)
n4_51 = np.array([[ 0.30273044, -0.2922017 ,  0.43413514,  0.40944204,  0.2726458 ],
       [ 0.08708785,  0.10180457,  0.26533896,  0.02013863, -0.08459854],
       [-0.04599554, -0.13979676,  0.11818553, -0.3175753 , -0.02257021],
       [ 0.11922223,  0.379405  , -0.1414416 , -0.14690988, -0.07628991],
       [ 0.06291172, -0.1170714 ,  0.11273405, -0.23567972, -0.21718118]],
      dtype=np.float32)

n4_64 = np.array([[ 7.2892445e-01, -3.6184496e-01,  7.5707376e-02, -2.2138792e-01,
         5.9102738e-01],
       [ 1.9770388e-01,  1.0074759e-01, -4.3718714e-01, -5.2505858e-02,
        -6.5304209e-03],
       [ 5.5445957e-01, -5.3677252e-03,  5.5579085e-02,  4.2651063e-01,
         2.9483497e-01],
       [-3.8618910e-01, -3.5562107e-01,  3.3985302e-01,  4.8872024e-02,
         1.0610015e-01],
       [-5.3176690e-02, -6.8732514e-04,  2.1459106e-01, -1.2867860e-01,
         2.4771778e-01]], dtype=np.float32)

n4_53_1 = np.array([[-0.38075498,  0.22878507, -0.2208733 , -0.09394305, -0.2707294 ],
       [-0.13987723, -0.06583323,  0.07896571,  0.03914308,  0.23975056],
       [-0.09774103,  0.01479102,  0.07021133, -0.28163898,  0.08627185],
       [ 0.01131247,  0.19056316, -0.02735321,  0.04826655, -0.07996862],
       [ 0.10656891, -0.0382387 , -0.19064929, -0.05785146,  0.04304903]],
      dtype=np.float32)

# lambda = 10
n4_53_2 = np.array([[-0.15105073, -0.00193107, -0.12186932, -0.19432059, -0.51581794],
       [ 0.2402732 , -0.16233152, -0.1819294 ,  0.08962011, -0.22061978],
       [ 0.04149335, -0.38727918, -0.0235681 , -0.00363646, -0.13351953],
       [ 0.10505434, -0.02459106, -0.08613595,  0.20032245,  0.04761972],
       [ 0.00921397,  0.04404994,  0.09038853,  0.06792428,  0.06227649]],
      dtype=np.float32)

n4_50_1 = np.array([[-0.6818201 , -0.30339962, -0.0117636 , -0.18771651,  0.02069637],
       [-0.55059755, -0.19168085, -0.09921675,  0.08788907, -0.572017  ],
       [-0.21839766,  0.20545708, -0.4235468 ,  0.21178274, -0.28833228],
       [ 0.08566236, -0.00877849, -0.26440084, -0.21796055,  0.33674678],
       [-0.3706525 , -0.21995409,  0.04666412, -0.00844946,  0.10202159]],
      dtype=np.float32)

n4_58 = np.array([[ 0.55933493,  0.09149887,  0.01621446,  0.33599952,  0.5792869 ],
       [ 0.02707325,  0.18067554, -0.146178  , -0.26904985,  0.2209711 ],
       [-0.04906826,  0.45524833,  0.25212032, -0.09817978,  0.62795216],
       [-0.5242689 , -0.04882664,  0.29519638, -0.19570878, -0.28538144],
       [ 0.19566853,  0.02749056, -0.37408343, -0.15427409, -0.43317074]],
      dtype=np.float32)

n4_50_2 = np.array([[-0.15105073, -0.00193107, -0.12186932, -0.19432059, -0.51581794],
       [ 0.2402732 , -0.16233152, -0.1819294 ,  0.08962011, -0.22061978],
       [ 0.04149335, -0.38727918, -0.0235681 , -0.00363646, -0.13351953],
       [ 0.10505434, -0.02459106, -0.08613595,  0.20032245,  0.04761972],
       [ 0.00921397,  0.04404994,  0.09038853,  0.06792428,  0.06227649]],
      dtype=np.float32)

# %%
# 5 classifiers

# lambda = 100 (optimal)

n5_58 = np.array([[-0.15325163, -0.41665685,  0.23701794,  0.16905364,  0.22373746],
       [-0.21645719, -0.1311658 ,  0.02748799, -0.2952281 ,  0.34431648],
       [-0.2766293 ,  0.17993148, -0.01659133, -0.24932249,  0.4098527 ],
       [-0.2731192 ,  0.39876652,  0.08035216,  0.14646745, -0.015938  ],
       [-0.02625623,  0.06762435, -0.4457163 , -0.1746802 ,  0.28746367]],
      dtype=np.float32)

n5_64 = np.array([[-0.19946668, -0.11764675, -0.39232412, -0.12734857, -0.04190942],
       [-0.24561465,  0.01633636, -0.3041285 , -0.17959742, -0.3792963 ],
       [-0.11315335,  0.1592017 ,  0.01393738,  0.06608199, -0.09443642],
       [ 0.13576032, -0.21927044,  0.14444019, -0.09787868,  0.13648732],
       [-0.30548087,  0.11081319,  0.07238704, -0.13110395,  0.12724933]],
      dtype=np.float32)

n5_73 = np.array([[-0.19356106,  0.38254875,  0.20876548,  0.09957773,  0.14371356],
       [ 0.3772746 , -0.20038168,  0.32133457,  0.37272435,  0.23895365],
       [ 0.23574032,  0.06650959,  0.09305757, -0.3318048 , -0.15366365],
       [ 0.09285784, -0.05745851, -0.38789964,  0.32379764, -0.11121555],
       [ 0.26345417, -0.12967917,  0.37163746,  0.01736946, -0.39764553]],
      dtype=np.float32)

n5_54 = np.array([[ 0.60274476, -0.18985306,  0.25763   ,  0.07528706, -0.10507763],
       [-0.23674877, -0.154956  ,  0.05179639,  0.45471954,  0.35754472],
       [ 0.13451834, -0.23672645, -0.17502639,  0.29166186, -0.24718651],
       [-0.22802909, -0.23489588,  0.23034939, -0.21457607,  0.11033209],
       [ 0.22497259, -0.2109895 , -0.08022083,  0.01155646, -0.11134812]],
      dtype=np.float32)

n5_56 = np.array([[ 0.00529527,  0.32360935, -0.15944353, -0.11735085, -0.1336738 ],
       [ 0.3065609 ,  0.3733928 ,  0.01621273, -0.24607854, -0.36194196],
       [ 0.02241707, -0.15271007,  0.0637633 ,  0.1536478 ,  0.06961245],
       [ 0.16653012,  0.06140433, -0.1380428 , -0.1705548 , -0.19049151],
       [-0.13508162,  0.12420242,  0.01696222,  0.2036412 ,  0.00894888]],
      dtype=np.float32)

# lambda = 10

n5_50 = np.array([[ 0.24663699,  0.3914765 ,  0.10944819,  0.30079305,  0.03399418],
       [ 0.2180989 ,  0.3687404 ,  0.04742846, -0.33041283, -0.40919846],
       [-0.19389746, -0.0570675 ,  0.50077915, -0.5494724 ,  0.15737683],
       [ 0.26524392,  0.02773325, -0.2841147 , -0.14127167, -0.15641916],
       [-0.19381757,  0.27121285,  0.06549436,  0.11498633,  0.08029481]],
      dtype=np.float32)

n5_63 = np.array([[ 0.3742756 ,  0.21378867,  0.32766616, -0.10967632,  0.34971073],
       [ 0.10787606, -0.32857737,  0.01522141, -0.1877685 ,  0.36522222],
       [-0.45946062, -0.01497582, -0.04744191,  0.1346399 ,  0.04840292],
       [ 0.11812817,  0.07586898, -0.01216165,  0.03332914,  0.10425153],
       [ 0.11150639, -0.3092564 ,  0.02041645,  0.14445248, -0.1699789 ]],
      dtype=np.float32)

n5_50_1 = np.array([[ 0.08813677, -0.1038722 , -0.00593317,  0.00584848, -0.411303  ],
       [-0.07212935,  0.02778929, -0.19752446,  0.07139108, -0.01777094],
       [ 0.19161284,  0.15476413,  0.02338236,  0.10611659, -0.25538883],
       [-0.00974002,  0.00091143, -0.0829509 , -0.12348379,  0.15926865],
       [-0.0519075 , -0.03062276, -0.04311853,  0.0691188 ,  0.01026522]],
      dtype=np.float32)

n5_63_1 = np.array([[-0.5646692 , -0.50508976, -0.15749428, -0.19047685, -0.32418758],
       [-0.03884638,  0.04562198,  0.1305631 , -0.1445755 , -0.37179598],
       [ 0.1554867 ,  0.02550909, -0.10959233,  0.12561294, -0.15281115],
       [-0.2235624 , -0.21270141,  0.10762567,  0.45916224, -0.06839128],
       [ 0.00589339, -0.2011389 , -0.09738092, -0.25158343,  0.23733076]],
      dtype=np.float32)

n5_50_2 = np.array([[-0.1624039 ,  0.06713212, -0.29594624, -0.0311302 ,  0.5151425 ],
       [-0.12696159, -0.06849018,  0.10219431,  0.5345756 ,  0.3473845 ],
       [ 0.21860929, -0.21322104, -0.4019593 ,  0.05010712,  0.29630676],
       [-0.23509449,  0.01598234,  0.22621466, -0.26277643, -0.1907201 ],
       [ 0.06423549,  0.24739192,  0.00329597, -0.19579704, -0.23327135]],
      dtype=np.float32)

# lambda = 1000

n5_57 = np.array([[-0.4920463 , -0.17797963,  0.12223208, -0.1722855 , -0.24290419],
       [-0.15291658,  0.27980912, -0.20833595,  0.00598423, -0.17389685],
       [-0.21162625,  0.07130908,  0.13010661,  0.337779  , -0.19053395],
       [-0.05028683, -0.01569924,  0.22803144,  0.35682112,  0.01855696],
       [ 0.31534192, -0.12882867, -0.00974855, -0.37066817, -0.16039242]],
      dtype=np.float32)

n5_51 = np.array([[-0.26835138, -0.24441169,  0.05776077,  0.05555359, -0.19186004],
       [-0.01591966, -0.10009346, -0.18060787, -0.1084349 ,  0.10387169],
       [ 0.00442084,  0.31291765, -0.24741001, -0.12938623,  0.033694  ],
       [ 0.20262244, -0.04401069,  0.06023926,  0.00522517, -0.1664902 ],
       [-0.30056012,  0.21149507,  0.17797436, -0.026977  , -0.09233361]],
      dtype=np.float32)

n5_55 = np.array([[ 0.42648655,  0.26193216,  0.18775289,  0.19343033,  0.19040394],
       [-0.05677687, -0.24823284,  0.06356346, -0.14366941, -0.01003412],
       [ 0.08579028,  0.27481723,  0.06363925, -0.25344837, -0.09006091],
       [ 0.22272597, -0.29103488, -0.00456523, -0.08808161,  0.06536464],
       [ 0.2522915 ,  0.04399155, -0.32204872,  0.01982412,  0.37370858]],
      dtype=np.float32)

n5_62 = np.array([[ 0.17378944,  0.21018437, -0.206832  , -0.23232248, -0.20012908],
       [ 0.42185396, -0.15122359,  0.26977238,  0.41308287, -0.3697059 ],
       [ 0.28845608, -0.4390146 , -0.2274422 , -0.308983  ,  0.16435733],
       [-0.31718555,  0.02717869, -0.13038757, -0.15404966,  0.45005164],
       [ 0.05585522, -0.14089668,  0.18893257,  0.19319163,  0.02906324]],
      dtype=np.float32)

n5_50_3 = np.array([[ 0.1514695 , -0.02257568, -0.2409771 ,  0.10167166,  0.43771723],
       [-0.21318229,  0.23449466,  0.07935412, -0.18224983,  0.36176813],
       [-0.16901265, -0.37793708,  0.29956317,  0.34988987,  0.06591564],
       [-0.14819597,  0.3648536 , -0.21304049, -0.16586639, -0.34294525],
       [-0.33561566, -0.18692714, -0.05884655,  0.19082795, -0.1594711 ]],
      dtype=np.float32)

# %%
# 6 classifiers

# lambda = 10 (optimal)
n6_50 = np.array([[ 0.5195208 ,  0.16873719,  0.4211151 , -0.12662509, -0.44297126],
       [ 0.22823219,  0.40345103,  0.40018713, -0.15180193, -0.06292637],
       [ 0.06238041,  0.24954155, -0.12350711, -0.23472434, -0.19491577],
       [ 0.33683932, -0.22602086, -0.26248503,  0.08534992,  0.18170097],
       [-0.28632137,  0.05878845,  0.36673227, -0.07661853, -0.31008142]],
      dtype=np.float32)

n6_50_1 = np.array([[ 0.1982145 , -0.50980943, -0.260793  ,  0.41530934,  0.20096172],
       [-0.17119752, -0.44810256,  0.3674793 ,  0.20038381,  0.28444844],
       [-0.20555384,  0.15328828,  0.10301269,  0.18714233,  0.13392636],
       [ 0.21485938, -0.28332788, -0.13328983, -0.05202411,  0.03424105],
       [ 0.11116111, -0.36278316,  0.11137337, -0.08824629,  0.26821357]],
      dtype=np.float32)

n6_75 = np.array([[ 0.09940689,  0.5150114 ,  0.26596397,  0.33995312,  0.55562216],
       [-0.08490133,  0.41094515,  0.30052453,  0.13044569, -0.12015278],
       [ 0.09840394, -0.44294727,  0.1613367 , -0.43043435, -0.12980077],
       [-0.11345105,  0.24226937, -0.01285548, -0.30903453,  0.07384666],
       [-0.07150064, -0.08565771,  0.28428283,  0.11019912, -0.32873556]],
      dtype=np.float32)

n6_50_2 = np.array([[-0.2698411 ,  0.01275641,  0.21765047,  0.3291091 ,  0.37686625],
       [-0.07398648, -0.40131414, -0.3679044 ,  0.01367613,  0.355531  ],
       [ 0.05511923, -0.13417932,  0.05494207,  0.42275625,  0.4665921 ],
       [-0.32846582, -0.15661804, -0.19566436,  0.14385065, -0.15727223],
       [ 0.10540928,  0.3575948 , -0.359265  ,  0.08301029,  0.13477406]],
      dtype=np.float32)

n6_65 = np.array([[-0.34956297, -0.34125856, -0.21382062, -0.3795524 , -0.11802451],
       [ 0.08234541, -0.13136989, -0.21688135, -0.13222335, -0.2749852 ],
       [ 0.0101292 ,  0.0354496 , -0.1300359 ,  0.07740866, -0.14653592],
       [-0.16875494,  0.03347873,  0.12567003, -0.04580142, -0.23515315],
       [ 0.08572435,  0.10264747, -0.17636205,  0.08616352, -0.08217523]],
      dtype=np.float32)

n6_50_3 = np.array([[-0.12658016,  0.20278944, -0.31855392, -0.43642366, -0.47705305],
       [-0.05145942,  0.1354868 , -0.37786707, -0.01707906, -0.12463955],
       [-0.0707259 ,  0.04308868, -0.06173025, -0.09295512, -0.12204562],
       [ 0.02271094,  0.2719132 ,  0.3172563 ,  0.09769669,  0.07986216],
       [-0.04624587, -0.15329097, -0.22288951, -0.18704285,  0.21530052]],
      dtype=np.float32)

# lambda = 100
n6_70 = np.array([[ 0.32591656, -0.0846523 , -0.07469238,  0.3622304 ,  0.01436355],
       [ 0.00337526, -0.19336289,  0.17919986,  0.41639867,  0.00257432],
       [ 0.4343813 ,  0.4090616 , -0.34876785,  0.15631993, -0.05684071],
       [ 0.12438106, -0.33219424,  0.06140859,  0.13825004,  0.11372583],
       [ 0.11011623, -0.17169227, -0.03667587, -0.02661308, -0.00871674]],
      dtype=np.float32)

n6_63 = np.array([[ 0.22747618,  0.25792474, -0.1679224 ,  0.10950913, -0.08016059],
       [ 0.20818584,  0.14670272, -0.00139121,  0.1359388 ,  0.3282388 ],
       [-0.07405314, -0.05781543,  0.28080425,  0.28131807,  0.06880002],
       [-0.06512055,  0.10339657,  0.12507515, -0.10585797, -0.16182677],
       [-0.16784844, -0.1320808 ,  0.03396834, -0.04828641, -0.07964387]],
      dtype=np.float32)

n6_56 = np.array([[ 0.18362439,  0.14545007,  0.15006605, -0.38335884, -0.02947569],
       [ 0.6448021 ,  0.22378787, -0.00551403, -0.44365695,  0.16429688],
       [-0.15627989, -0.2850269 , -0.19392413,  0.10765089, -0.39873925],
       [-0.16248639, -0.0696497 ,  0.11801006,  0.08744019,  0.06886759],
       [-0.18100144, -0.05130267, -0.14045872, -0.23836759,  0.21206053]],
      dtype=np.float32)

n6_50_4 = np.array([[-0.07122768, -0.20761526,  0.05218966, -0.45267546, -0.44242567],
       [-0.40662852,  0.18393384,  0.29248992, -0.21557842, -0.2567599 ],
       [-0.18768935, -0.1264193 ,  0.10327671, -0.30340472,  0.3707867 ],
       [-0.03298751, -0.21023229,  0.09651851, -0.31116724, -0.2078688 ],
       [-0.14649668,  0.0630491 , -0.01375389, -0.11583368,  0.00248944]],
      dtype=np.float32)

n6_58 = np.array([[-0.6502994 , -0.17368557, -0.1070004 , -0.14870705,  0.22588396],
       [-0.34378666, -0.50661623, -0.29592478, -0.40626916, -0.38697678],
       [ 0.29460526,  0.2997705 , -0.03023726, -0.40523866,  0.20298672],
       [-0.09072918,  0.25732827, -0.39372548,  0.12433089,  0.09943121],
       [ 0.01693829,  0.42790186, -0.03246072,  0.08851986, -0.12603632]],
      dtype=np.float32)

n6_50_5 = np.array([[-0.2225775 , -0.03303711,  0.16649818,  0.45663404,  0.3280125 ],
       [-0.15465991,  0.09729604, -0.19169913,  0.41610423,  0.00268167],
       [-0.3452078 , -0.27421936,  0.11724163,  0.0295067 , -0.2099042 ],
       [ 0.16696393,  0.15322527, -0.13202275,  0.03558733,  0.05779188],
       [ 0.36454678, -0.12143804,  0.04639579,  0.25842175, -0.10466121]],
      dtype=np.float32)

# lambda = 1
n6_62 = np.array([[-4.11619961e-01, -5.25110006e-01,  5.04994765e-02,
        -5.51865697e-01, -2.46197715e-01],
       [ 2.75992602e-01,  1.98958665e-01, -3.11795305e-02,
         2.84914076e-01, -3.02054644e-01],
       [-2.32013017e-01, -4.60866928e-01, -1.67314708e-01,
        -3.47348116e-02, -1.99884653e-01],
       [ 3.14138740e-01, -2.58924701e-04,  1.58848479e-01,
         1.35494813e-01,  2.72186846e-01],
       [-2.03849688e-01,  1.05165206e-01,  2.21818969e-01,
         5.75607121e-02, -2.20885485e-01]], dtype=np.float32)

n6_63_1 = np.array([[ 0.10057274,  0.11006621,  0.14042547,  0.36601594, -0.26947352],
       [-0.7706294 , -0.34285507,  0.00726717, -0.602607  , -0.32731986],
       [-0.2775319 ,  0.18968178,  0.31556574,  0.02927412, -0.4110973 ],
       [-0.16120209,  0.03221664, -0.1827809 ,  0.02967574, -0.17692962],
       [ 0.0289845 ,  0.15876554, -0.11422868,  0.00173614,  0.10827182]],
      dtype=np.float32)

n6_52 = np.array([[ 0.3051023 ,  0.24389067,  0.05110785,  0.5018826 ,  0.60018456],
       [ 0.32135648,  0.36647138, -0.06880983,  0.13064268,  0.39205006],
       [ 0.6062105 ,  0.25106782, -0.04993558,  0.20555572,  0.54946107],
       [-0.22997352, -0.10446329, -0.32724553, -0.12151342,  0.04394555],
       [-0.07849986,  0.13527443, -0.32938784, -0.02754251, -0.279683  ]],
      dtype=np.float32)

n6_59 = np.array([[-0.445916  , -0.6106575 ,  0.11604688,  0.09287349, -0.5431132 ],
       [ 0.25912336, -0.6350394 , -0.3776919 , -0.17157832, -0.48493966],
       [-0.03423082,  0.3836399 , -0.06202522, -0.1927142 , -0.12923868],
       [-0.42124096, -0.0183802 ,  0.4871136 , -0.04986412, -0.27752227],
       [ 0.43924916, -0.25126237,  0.00527764, -0.12745334,  0.004467  ]],
      dtype=np.float32)

n6_50_6 = np.array([[-0.03505139,  0.38040575, -0.31114745, -0.42783725, -0.28629184],
       [-0.37124527,  0.15228441,  0.1875445 ,  0.00202753,  0.01080948],
       [-0.34518516, -0.27171758, -0.03266708, -0.14756995, -0.07415741],
       [ 0.2644235 ,  0.01139302,  0.02481723, -0.12386212,  0.15157542],
       [-0.04023441, -0.15083162,  0.14170602,  0.03177655,  0.23979369]],
      dtype=np.float32)

n6_50_7 = np.array([[ 0.27680108,  0.18006624, -0.01812302,  0.02988872,  0.448246  ],
       [ 0.21553533,  0.1000341 ,  0.12079685,  0.19068591,  0.40514785],
       [ 0.20193835, -0.03451864, -0.03286666,  0.07238971,  0.14963348],
       [ 0.05134158,  0.00203431, -0.1418732 ,  0.04985983, -0.09187339],
       [-0.11325574, -0.03756154, -0.01660616, -0.01474852,  0.02415235]],
      dtype=np.float32)

# %% [markdown]
# ### Plots for optimal lambda

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize = (20, 15))
images_optimal = [n2_63, n2_60, n3_62, n3_60, n3_52, n4_74, n4_65, n4_55, n4_53, n5_73, n5_64, n5_58, n5_56,n5_54, n6_75,
                  n6_65, n6_50, n6_50_1, n6_50_2, n6_50_3]

title_optimal = ['2 Cl 63 %', '2 Cl 60 %', '3 Cl 62 %', '3 Cl 60 %', '3 Cl 52 %', '4 Cl 74 %', '4 Cl 65 %', '4 Cl 55 %', '4 Cl 53 %',
                 '5 Cl 73 %', '5 Cl 64 %', '5 Cl 58 %', '5 Cl 56 %', '5 Cl 54 %', '6 Cl 75 %', '6 Cl 65 %', '6 Cl 50 %', '6 Cl 50 %',
                 '6 Cl 50 %', '6 Cl 50 %']

index_optimal = [1, 2, 7, 8, 9, 13, 14, 15, 16, 19, 20, 21, 22, 23, 25, 26, 27, 28, 29, 30]
for im in range(len(images_optimal)):
    plt.subplot(5, 6, index_optimal[im]) 
    plt.imshow(images_optimal[im])
    plt.colorbar()
    plt.title(title_optimal[im])
plt.show()

# %% [markdown]
# ### Plots for optimal lambda * 0.1

# %%
plt.figure(figsize = (20, 15))
images_suboptimal = [n2_62, n2_55, n3_61, n3_52_1, n3_50, n4_58, n4_53_2, n4_50_1, n4_50_2, n5_63, n5_63_1, n5_50, n5_50_1,
                     n5_50_2, n6_63_1, n6_62, n6_59, n6_52, n6_50_6, n6_50_7]

title_suboptimal = ['2 Cl 62 %', '2 Cl 55 %', '3 Cl 61 %', '3 Cl 52 %', '3 Cl 50 %', '4 Cl 58 %', '4 Cl 53 %', '4 Cl 50 %',
                    '4 Cl 50 %', '5 Cl 63 %', '5 Cl 63 %', '5 Cl 50 %', '5 Cl 50 %', '5 Cl 50 %', '6 Cl 63 %', '6 Cl 62 %',
                    '6 Cl 59 %', '6 Cl 52 %', '6 Cl 50 %', '6 Cl 50 %']

index_suboptimal = [1, 2, 7, 8, 9, 13, 14, 15, 16, 19, 20, 21, 22, 23, 25, 26, 27, 28, 29, 30]
for im in range(len(images_suboptimal)):
    plt.subplot(5, 6, index_suboptimal[im]) 
    plt.imshow(images_suboptimal[im])
    plt.colorbar()
    plt.title(title_suboptimal[im])
plt.show()

# %% [markdown]
# ### Plots for optimal lambda * 10

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize = (20, 15))
images_supoptimal = [n2_59, n2_58, n3_53, n3_52_2, n3_51, n4_64, n4_53_1, n4_51, n4_50, n5_62, n5_57, n5_55, n5_51, n5_50_3,
                     n6_70, n6_63, n6_58, n6_56, n6_50_4, n6_50_5]
title_supoptimal = ['2 Cl 59 %', '2 Cl 58 %', '3 Cl 53 %', '3 Cl 52 %', '3 Cl 51 %', '4 Cl 64 %', '4 Cl 53 %', '4 Cl 51 %',
                    '4 Cl 50 %', '5 Cl 62 %', '5 Cl 57 %', '5 Cl 55 %', '5 Cl 51 %', '5 Cl 50 %', '6 Cl 70 %', '6 Cl 63 %',
                    '6 Cl 58 %', '6 Cl 56 %', '6 Cl 50 %', '6 Cl 50 %']

index_supoptimal = [1, 2, 7, 8, 9, 13, 14, 15, 16, 19, 20, 21, 22, 23, 25, 26, 27, 28, 29, 30]
for im in range(len(images_supoptimal)):
    plt.subplot(5, 6, index_supoptimal[im]) 
    plt.imshow(images_supoptimal[im])
    plt.colorbar()
    plt.title(title_supoptimal[im])
plt.show()

# %% [markdown]
# ### Results for 3 * 3 filter (Single classifier achieves 65% accuracy)

# %%
# lambda = 1
n2_62_lmda1 = np.array([[-0.14962894,  0.16675861,  0.44367495],
       [-0.3648717 , -0.07171379,  0.06803348],
       [ 0.2381107 , -0.17164557, -0.06425899]], dtype=np.float32)

n2_51_lmda1 = np.array([[ 0.43763033, -0.19688123, -0.7313212 ],
       [ 0.8443185 ,  0.25777185, -0.01803073],
       [-0.43540382,  0.43585768,  0.19176315]], dtype=np.float32)

# lambda = 10 (optimal)
n2_63_lmda10 = np.array([[-0.7370466 , -0.03341911, -0.18451153],
       [-0.12902234,  0.15580493, -0.6755435 ],
       [ 0.32866526, -0.07682031, -0.64941496]], dtype=np.float32)

n2_66_lmda10 = np.array([[ 0.38227537, -0.01555743,  0.0945228 ],
       [ 0.06713014, -0.08110442,  0.35179907],
       [-0.1705738 ,  0.03925899,  0.3359359 ]], dtype=np.float32)

# lambda = 100
n2_64_lmda100 = np.array([[-0.41246274, -0.27285022, -0.359028  ],
       [ 0.0214018 , -0.6035216 ,  0.8095977 ],
       [-0.06924816, -0.56144434, -0.16072528]], dtype=np.float32)

n2_63_lmda100 = np.array([[ 0.2975219 ,  0.19631007,  0.25927174],
       [-0.02748382,  0.435139  , -0.58650094],
       [ 0.02707927,  0.40550613,  0.11603462]], dtype=np.float32)

# %%
# 3 classifiers    
# lambda = 100
n3_53_lmda100 = np.array([[ 0.01274363, -0.02471993, -0.37054974],
       [ 0.077178  , -0.31484818,  0.20513861],
       [ 0.2302257 ,  0.09983245, -0.5057084 ]], dtype=np.float32)
                      
n3_57_lmda100 = np.array([[-0.7041362 , -0.54940957, -0.10897277],
       [-0.26090404,  0.75919175,  0.21784186],
       [-0.22674045,  0.08807326,  0.37481418]], dtype=np.float32)
                      
n3_70_lmda100 = np.array([[ 0.65774804,  0.5208853 ,  0.6686    ],
       [ 0.12544149, -0.35163164, -0.5460531 ],
       [-0.12324862,  0.00337787,  0.39086103]], dtype=np.float32)
                      
# lambda = 1000 (optimal)
n3_63_lmda1000 = np.array([[-0.19936928, -0.16205543,  0.5907826 ],
       [-0.5727831 , -0.23268947, -0.41165587],
       [ 0.09067153, -0.4821478 , -0.15571858]], dtype=np.float32)
                      
n3_71_lmda1000 = np.array([[ 0.25384575,  0.39132643, -0.13100001],
       [ 0.33740428,  0.30790114, -0.01949275],
       [-0.23090154,  0.10400392,  0.5847726 ]], dtype=np.float32)
                      
n3_57_lmda1000 = np.array([[ 0.03707274, -0.21783566, -0.3095813 ],
       [ 0.1530526 ,  0.03251749,  0.27534372],
       [ 0.09043046,  0.2307314 , -0.3268902 ]], dtype=np.float32)          
                      
# lambda = 10000
n3_52_lmda10000 = np.array([[0.03772932, 0.0341519 , 0.22162685],
       [0.02386053, 0.12031098, 0.35917458],
       [0.32516226, 0.11133157, 0.03703238]], dtype=np.float32)
        
n3_67_lmda10000 = np.array([[-0.44113988, -0.6589887 , -0.14706999],
       [ 0.127318  , -0.13413946,  0.04242891],
       [-0.1359562 ,  0.01424865,  0.02930582]], dtype=np.float32)
                      
n3_59_lmda10000 = np.array([[ 0.44905108,  0.7023439 , -0.16426636],
       [ 0.11357091, -0.07118952, -0.724693  ],
       [-0.43115196, -0.22796024, -0.09158503]], dtype=np.float32)

# %% [markdown]
# ### REDO BELOW...

# %%
# lambda = 10
n4_65_lmda10 = np.array([[-0.79340833,  0.32593614, -0.43599197],
       [-0.8872447 , -0.13085876, -0.7033935 ],
       [-0.02956322, -0.4934293 , -0.03779953]], dtype=np.float32)

n4_50_lmda10 = np.array([[ 0.5218646 ,  0.30441624, -0.34469754],
       [ 0.40029272, -0.19842225,  0.03752327],
       [ 0.29175723, -0.09530739, -0.738236  ]], dtype=np.float32)

n4_55_lmda10 = np.array([[-0.24088342, -0.42302352,  0.06513371],
       [-0.1554828 ,  0.05906947,  0.21503831],
       [-0.22901608,  0.13725631, -0.01284367]], dtype=np.float32)

n4_77_lmda10 = np.array([[ 0.522684  ,  0.09389599,  0.5752794 ],
       [ 0.6017017 , -0.04429832,  0.19581375],
       [ 0.04550178,  0.2344752 ,  0.7080207 ]], dtype=np.float32)


# lambda = 100 
n4_73_lmda100 = np.array([[ 0.19675024,  0.71535677, -0.50410604],
       [-0.10655107,  0.48711154,  0.22307715],
       [ 0.12224485,  0.37720254,  0.22001882]], dtype=np.float32)
n4_55_lmda100 = np.array([[-0.03737688, -0.30242825,  0.33962062],
       [ 0.02543892,  0.18614426,  0.0138358 ],
       [ 0.02229767, -0.35968816,  0.04798789]], dtype=np.float32) 
n4_62_lmda100 = np.array([[ 0.1140323 , -0.05158187,  0.29350686],
       [ 0.35062307, -0.05008418, -0.24059556],
       [ 0.34799135, -0.22776733, -0.14279653]], dtype=np.float32)
n4_62_lmda100_1 = np.array([[ 0.23177987, -0.03521391, -0.53443867],
       [-0.5368893 , -0.7529413 ,  0.2715733 ],
       [-0.7983541 ,  0.7308931 , -0.11647978]], dtype=np.float32)

# lambda = 1000
n4_66_lmda1000 = np.array([[ 0.69651175, -0.6517352 ,  0.00950631],
       [-0.01806232, -0.05886501,  0.3853763 ],
       [ 0.257705  , -0.20035185,  0.63634706]], dtype=np.float32)

n4_56_lmda1000 = np.array([[-0.33330545,  0.33712626,  0.17336704],
       [-0.17931396,  0.05745278,  0.08166434],
       [ 0.06699263,  0.35539258, -0.3898211 ]], dtype=np.float32)

n4_68_lmda1000 = np.array([[ 0.00619289,  0.33353212,  0.37885007],
       [ 0.4034236 ,  0.16548397, -0.7038231 ],
       [-0.36439288,  0.3112423 ,  0.03244075]], dtype=np.float32)

n4_70_lmda1000 = np.array([[-0.16456689,  0.12924868, -0.36772263],
       [-0.12885514, -0.11017849,  0.17741783],
       [ 0.02726705, -0.35990793, -0.11030719]], dtype=np.float32)

# %%
# 5 classifiers
# lambda = 0.1 (optimal)
n5_66_lmda0p1 = np.array([[-0.4981651 , -0.5790563 , -0.24306552],
       [ 0.29222554,  0.21208334, -0.14609501],
       [-0.5908822 ,  0.09613199, -0.12515756]], dtype=np.float32)

n5_59_lmda0p1 = np.array([[-0.37748396, -0.21549253, -0.02866126],
       [-0.11166612,  0.09768753, -0.4140068 ],
       [ 0.05369515, -0.3886032 , -0.356795  ]], dtype=np.float32)

n5_60_lmda0p1 = np.array([[-0.30870372, -0.75059813, -0.12578036],
       [-0.45331532, -0.8649913 ,  0.5527105 ],
       [-0.41938686,  0.38997492,  0.03831596]], dtype=np.float32)

n5_79_lmda0p1 = np.array([[ 0.8526043 ,  0.65925926, -0.09650793],
       [ 0.13167156,  0.4016198 ,  0.28514898],
       [ 0.15724552,  0.27834836,  0.09880096]], dtype=np.float32)

n5_79_lmda0p1_1 = np.array([[ 0.2459644 ,  0.78531563,  0.36349824],
       [ 0.06867795, -0.00513337, -0.17839101],
       [ 0.70959   , -0.24979258,  0.42951238]], dtype=np.float32)

# lambda = 1
n5_60_lmda1 = np.array([[ 0.06065887, -0.00878696,  0.07473521],
       [ 0.5276259 ,  0.6193952 ,  0.03210594],
       [ 0.7121311 ,  0.00967164,  0.24503148]], dtype=np.float32)

n5_63_lmda1 = np.array([[-0.45021766, -0.33415937, -0.5869708 ],
       [ 0.19998072, -0.256706  , -0.03750772],
       [-0.65951484,  0.30793858, -0.58733845]], dtype=np.float32)

n5_72_lmda1 = np.array([[ 0.34830385,  0.3361905 ,  0.520159  ],
       [ 0.01889819,  0.18674122,  0.02513973],
       [-0.43420935, -0.12160854, -0.4865653 ]], dtype=np.float32)

n5_51_lmda1 = np.array([[-0.03925025,  0.1796932 ,  0.5033328 ],
       [-0.506307  , -0.4410732 ,  0.57299775],
       [ 0.11780193,  0.7089128 ,  0.88553196]], dtype=np.float32)

n5_55_lmda1 = np.array([[-0.10233665, -0.21147998, -0.5464967 ],
       [-0.2682019 , -0.16744664, -0.3568302 ],
       [ 0.26679403, -0.6792963 ,  0.10539674]], dtype=np.float32)

# lambda = 0.01
n5_65_lmda0p01 = np.array([[-0.6984659 , -0.5776071 , -0.537447  ],
       [-0.30683064, -0.27448043,  0.4165433 ],
       [-0.09059415,  0.1246535 , -0.45273173]], dtype=np.float32)
n5_51_lmda0p01 = np.array([[ 0.72704136,  0.03975865, -0.34218854],
       [ 0.65516114,  0.5299887 , -0.31405196],
       [ 0.5360931 ,  0.5557024 , -0.13935429]], dtype=np.float32)
n5_51_lmda0p01_1 = np.array([[ 0.2875012 , -0.32731548, -0.8283892 ],
       [ 0.32141557, -0.654816  , -0.25060827],
       [-0.2565516 , -0.1704388 , -0.5380697 ]], dtype=np.float32)
n5_50_lmda0p01 = np.array([[-0.0736728 ,  0.42068204,  0.6545501 ],
       [-0.2835059 , -0.21499436,  0.26156673],
       [ 0.00603243, -0.00776302,  0.2551933 ]], dtype=np.float32) 
n5_70_lmda0p01 = np.array([[ 0.41399324,  0.1704697 ,  0.6998411 ],
       [ 0.52339137,  0.65375614, -0.29631263],
       [-0.6360565 , -0.6414377 , -0.2936755 ]], dtype=np.float32)

# %%
# 6 classifiers

# lambda = 0.1
n6_66_0p1 = np.array([[-0.08799976,  0.65071785,  0.6293928 ],
       [ 0.5858755 , -0.35145742, -0.6963146 ],
       [ 0.04736975,  0.22390193, -0.3840037 ]], dtype=np.float32)

n6_56_0p1 = np.array([[-0.2781229 , -0.56863093,  0.02387112],
       [-0.5780489 , -0.08690216, -0.34855658],
       [-0.39074048, -0.16521008, -0.31210107]], dtype=np.float32)

n6_80_0p1 = np.array([[ 0.30414063,  0.13872543, -0.48093435],
       [-0.01937834,  0.61114573,  0.7522157 ],
       [ 0.5119563 ,  0.8693527 , -0.12090821]], dtype=np.float32)

n6_64_0p1 = np.array([[ 0.6545961 ,  0.4977506 ,  0.22577913],
       [-0.16323137, -0.15318389,  0.5801647 ],
       [-0.63553095, -0.69688296,  0.24548031]], dtype=np.float32)

n6_53_0p1 = np.array([[ 0.39104   , -0.3239794 ,  0.24635309],
       [ 0.8055089 ,  0.26308438, -0.4550206 ],
       [ 0.9783584 , -0.4113324 , -0.2089115 ]], dtype=np.float32)

n6_53_0p1_1 = np.array([[-0.5239999 ,  0.28633985, -0.3279103 ],
       [-0.01446028,  0.35491684,  0.6139162 ],
       [-0.11725172,  0.47943047,  1.0058434 ]], dtype=np.float32)

# lambda  = 1 (optimal)
n6_71_lmda1 = np.array([[ 0.05596237, -0.0603561 ,  0.48969984],
       [ 0.74099445,  0.4027786 ,  0.6138898 ],
       [-0.37096968, -0.30216926, -0.1740863 ]], dtype=np.float32)

n6_80_lmda1 = np.array([[ 0.83476025, -0.20219928,  0.4530078 ],
       [ 0.11829872,  0.6157102 ,  0.4659121 ],
       [-0.2730654 ,  0.879447  ,  0.29897928]], dtype=np.float32)

n6_52_lmda1 = np.array([[ 0.04480957, -0.28527603, -0.7296227 ],
       [-0.5861079 ,  0.01556496, -0.30237094],
       [ 0.49764144, -0.4048814 , -0.15580411]], dtype=np.float32)

n6_63_lmda1 = np.array([[-0.5717793 , -0.1835541 , -0.42004573],
       [-0.65919816, -0.59721774, -0.13834642],
       [ 0.14146899, -0.25499004, -0.02189679]], dtype=np.float32)

n6_81_lmda1 = np.array([[-0.13318355,  0.7853436 ,  0.03689963],
       [ 0.21564183,  0.44263843, -0.18270962],
       [ 0.27037668, -0.1111924 ,  0.43265444]], dtype=np.float32)

n6_67_lmda1 = np.array([[-0.19708323, -0.2402066 ,  0.1223989 ],
       [ 0.17711851, -0.7777501 , -0.4192425 ],
       [-0.38592046,  0.26186463, -0.42919376]], dtype=np.float32)


# lambda  = 10
n6_78_lmda10 = np.array([[ 0.57408994,  0.37876615, -0.04169768],
       [-0.18393585,  0.1192723 ,  0.1019472 ],
       [ 0.04331961,  0.19639175,  0.503966  ]], dtype=np.float32)

n6_61_lmda10 = np.array([[-0.6208737 , -0.7511286 ,  0.38589466],
       [-0.4537125 , -0.7300893 , -0.08221664],
       [ 0.2514962 ,  0.03126436, -0.04175954]], dtype=np.float32)

n6_59_lmda10 = np.array([[-0.80637115,  0.41782132, -0.18755382],
       [-0.6182558 ,  0.06986868,  0.13392964],
       [ 0.20739971,  0.20996107, -0.66949236]], dtype=np.float32)

n6_80_lmda10 = np.array([[ 0.37941763,  0.33459696,  0.09296699],
       [ 0.0724363 ,  0.11480202,  0.15790793],
       [-0.11345601, -0.01238942,  0.22597374]], dtype=np.float32)

n6_68_lmda10 = np.array([[-0.5412064 , -0.17803533, -0.30324438],
       [ 0.53789246, -0.16892956, -0.21817079],
       [-0.6776943 , -0.32784146,  0.18143669]], dtype=np.float32)

n6_63_lmda10 = np.array([[ 0.4419098 , -0.6937534 , -0.25346047],
       [ 0.4839863 ,  0.3570884 , -0.41164654],
       [ 0.338872  , -0.2479411 , -0.64190894]], dtype=np.float32)

# %% [markdown]
# ### Plots for optimal lambda

# %%
plt.figure(figsize = (25, 20))
images_optimal = [n2_66_lmda10, n2_63_lmda10, n3_71_lmda1000, n3_63_lmda1000, n3_57_lmda1000, n4_77_lmda10, n4_65_lmda10, 
                 n4_55_lmda10, n4_50_lmda10, n5_79_lmda0p1, n5_79_lmda0p1_1, n5_66_lmda0p1, n5_60_lmda0p1, n5_59_lmda0p1,
                 n6_81_lmda1, n6_80_lmda1, n6_71_lmda1, n6_67_lmda1, n6_63_lmda1, n6_52_lmda1]

title_optimal = ['2 cl 66 %', '2 cl 63 %', '3 cl 71 %', '3 cl 63 %', '3 cl 57 %', '4 cl 77 %', '4 cl 65 %', '4 cl 55 %',
                 '4 cl 50 %', '5 cl 79 %', '5 cl 79 %', '5 cl 66 %', '5 cl 60 %', '5 cl 59 %', '6 cl 81 %', '6 cl 80 %',
                 '6 cl 71 %', '6 cl 67 %', '6 cl 63 %', '6 cl 52 %']

index_optimal = [1, 2, 7, 8, 9, 13, 14, 15, 16, 19, 20, 21, 22, 23, 25, 26, 27, 28, 29, 30]
for im in range(len(images_optimal)):
    plt.subplot(5, 6, index_optimal[im]) 
    plt.imshow(images_optimal[im])
    plt.colorbar()
    plt.title(title_optimal[im])
plt.show()

# %% [markdown]
# ### Plots for optimal lambda * 0.1

# %%
plt.figure(figsize = (25, 20))
images_optimal = [n2_62_lmda1, n2_51_lmda1, n3_70_lmda100, n3_57_lmda100, n3_53_lmda100, n4_73_lmda100, n4_62_lmda100,
                  n4_62_lmda100_1,  n4_55_lmda100, n5_70_lmda0p01, n5_65_lmda0p01, n5_51_lmda0p01, n5_51_lmda0p01_1, 
                 n5_50_lmda0p01, n6_80_0p1, n6_66_0p1, n6_64_0p1, n6_56_0p1, n6_53_0p1, n6_53_0p1_1]

title_optimal = ['2 cl 62 %', '2 cl 51 %', '3 cl 70 %', '3 cl 57 %', '3 cl 53 %', '4 cl 73 %', '4 cl 62 %', '4 cl 62 %',
                 '4 cl 55 %', '5 cl 70 %', '5 cl 65 %', '5 cl 51 %', '5 cl 51 %', '5 cl 50 %', '6 cl 80 %', '6 cl 66 %',
                 '6 cl 64 %', '6 cl 56 %', '6 cl  53 %', '6 cl 53 %']

index_optimal = [1, 2, 7, 8, 9, 13, 14, 15, 16, 19, 20, 21, 22, 23, 25, 26, 27, 28, 29, 30]
for im in range(len(images_optimal)):
    plt.subplot(5, 6, index_optimal[im]) 
    plt.imshow(images_optimal[im])
    plt.colorbar()
    plt.title(title_optimal[im])
plt.show()

# %% [markdown]
# ### Plots for optimal lambda * 10

# %%
plt.figure(figsize = (25, 20))
images_optimal = [n2_64_lmda100, n2_63_lmda100, n3_67_lmda10000, n3_59_lmda10000, n3_52_lmda10000, n4_70_lmda1000,
                  n4_68_lmda1000, n4_66_lmda1000, n4_56_lmda1000, n5_72_lmda1, n5_63_lmda1, n5_60_lmda1,
                 n5_55_lmda1, n5_51_lmda1, n6_80_lmda10, n6_78_lmda10, n6_68_lmda10, n6_63_lmda10, n6_61_lmda10, n6_59_lmda10]

title_optimal = ['2 cl 64 %', '2 cl 63 %', '3 cl 67 %', '3 cl 59 %', '3 cl 52 %', '4 cl 70 %', '4 cl 68 %', '4 cl 66 %',
                 '4 cl 56 %', '5 cl 72 %', '5 cl 63 %', '5 cl 60 %', '5 cl 55 %', '5 cl 51 %', '6 cl 80 %', '6 cl 78 %',
                 '6 cl 68 %', '6 cl 63 %', '6 cl 61 %', '6 cl 59 %']

index_optimal = [1, 2, 7, 8, 9, 13, 14, 15, 16, 19, 20, 21, 22, 23, 25, 26, 27, 28, 29, 30]
for im in range(len(images_optimal)):
    plt.subplot(5, 6, index_optimal[im]) 
    plt.imshow(images_optimal[im])
    plt.colorbar()
    plt.title(title_optimal[im])
plt.show()

# %% [markdown]
# ### Horizontal versus Vertical patch experiment

# %% [markdown]
# 5 * 2 patch - Training on patch and testing on patchless achieves 94% accuracy, so need a bigger size
# So, 15 * 5 patch added. A single model achieves target accuracy of 65 %

# %%
# 2 classifiers

# lambda = 10
N2_64_l10 = array([[ 0.34362295, -0.09551003, -0.10729734],
       [ 0.2388231 , -0.44433993, -0.7077105 ],
       [-0.0068864 ,  0.12886326,  0.12863657]], dtype=float32)

N2_66_l10 = array([[-0.452359  ,  0.14053679,  0.16661777],
       [-0.30848837,  0.607543  ,  0.9531019 ],
       [ 0.01495054, -0.1547696 , -0.1486291 ]], dtype=float32)

# lambda = 100 (optimal)
N2_63_l100 = array([[-0.11107953,  0.29988304,  0.5421094 ],
       [-0.36973634,  0.3659595 , -0.07069037],
       [ 0.02790221, -0.07975145,  0.1379441 ]], dtype=float32)

N2_67_l100 = array([[ 0.18021688, -0.46518996, -0.8527446 ],
       [ 0.58482677, -0.5756765 ,  0.11976426],
       [-0.0383408 ,  0.13067986, -0.20103838]], dtype=float32)

# lambda = 1000
N2_60_l1000 = array([[-0.10734312, -0.34647042, -0.03379791],
       [ 0.02414418,  0.02555045, -0.00685094],
       [-0.10480135, -0.5436173 ,  0.58116865]], dtype=float32)

N2_66_l1000 = array([[ 0.134583  ,  0.43041685,  0.04541443],
       [-0.02650314, -0.02811866,  0.01085988],
       [ 0.1323083 ,  0.6762195 , -0.71530515]], dtype=float32)

# %%
# 3 classifiers

# lambda = 10
N3_58_l10 = array([[-0.28271547, -0.17349881,  0.09060073],
       [-0.09158091,  0.07341278, -0.4328182 ],
       [-0.3601506 , -0.3364952 , -0.0009506 ]], dtype=float32)

N3_62_l10 = array([[ 0.00320469,  0.2054534 ,  0.03527524],
       [-0.32501018,  0.07875746,  0.23801084],
       [-0.06096423,  0.4372534 ,  0.62112737]], dtype=float32)

N3_60_l10 = array([[ 0.55287737,  0.06827819, -0.05570677],
       [ 0.69475675, -0.17751789,  0.45044535],
       [ 0.72481686, -0.00581824, -0.67043644]], dtype=float32)  

# lambda = 100 (optimal)
N3_58_l100 = array([[-0.03474548,  0.32776707,  0.25026584],
       [ 0.03120466, -0.13548137,  0.14306533],
       [ 0.31206787,  0.29875892,  0.22451444]], dtype=float32)

N3_72_l100 = array([[ 0.6707526 , -0.34665534, -0.21824344],
       [ 0.34945107, -0.25192952,  0.19561261],
       [-0.7665374 , -0.6720523 , -0.20458265]], dtype=float32)

N3_58_l100_1 = array([[-0.5644971 , -0.23543169, -0.06414002],
       [-0.30018672,  0.30538765, -0.03493826],
       [ 0.27286935,  0.17090645, -0.01885139]], dtype=float32)

# lambda = 1000
N3_70_l1000 = array([[ 0.2200824 ,  0.3089358 , -0.0895615 ],
       [ 0.45190358, -0.1904056 , -0.40719047],
       [-0.5026324 , -0.02339386, -0.542271  ]], dtype=float32)

N3_54_l1000 = array([[ 0.357435  , -0.01269818, -0.1432766 ],
       [-0.21190488,  0.29743892,  0.367904  ],
       [-0.03666538,  0.10066769,  0.459233  ]], dtype=float32)

N3_66_l1000 = array([[-0.6420802 , -0.30056792,  0.21951747],
       [-0.20605332, -0.18766578, -0.07950852],
       [ 0.5368142 , -0.11198141, -0.04876892]], dtype=float32)

# %%
# 4 classifiers

# lambda - 1

N4_73_l1 = array([[ 0.14863454,  0.14809458,  0.21533225],
       [ 0.3936646 , -0.02869898,  0.32078987],
       [-0.98116255, -0.2695847 , -0.38513127]], dtype=float32)

N4_51_l1 = array([[ 6.4246106e-01, -3.8048199e-01, -3.8125771e-01],
       [-5.8275771e-01,  4.9315923e-01, -4.0715224e-01],
       [-6.6228159e-02, -5.4574537e-04,  6.6899635e-02]], dtype=float32)

N4_57_l1 = array([[-1.6211611 , -0.527634  , -0.76210994],
       [-0.07321657, -0.49623165,  1.3269376 ],
       [ 1.2614186 ,  0.35256973, -0.4886924 ]], dtype=float32)

N4_52_l1 = array([[-0.0027341 ,  0.33206514,  0.40293947],
       [ 0.00317683, -0.37078837, -1.1196946 ],
       [-0.00669132, -0.15931876,  0.47823116]], dtype=float32)
