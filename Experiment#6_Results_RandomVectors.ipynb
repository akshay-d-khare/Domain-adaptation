# %%
# a = [[-0.3342,  0.5757, -0.5677,  0.3217, -0.0245,  0.3612]]

# mu = 0.001 (20 epochs)
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.64, 0.65, 0.67]
w_source_trained = [[ 0.3494,  0.6022, -0.2687,  0.5565, -0.5739, -0.1299]]

# mu = 0.01 (20 epochs)
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.71, 0.69, 0.71]
w_source_trained = [[-0.0199,  1.4982,  0.0266,  1.3502, -0.8933, -0.2288]]

# mu = 0.1 (20 epochs)
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.91, 0.90, 0.91]
w_source_trained = [[ 0.3225,  0.4616,  0.1733,  1.3706, -1.1021, -0.7643]]

# For mu = 1, source acc falls to 90%

# %%
# a = tensor([[-0.6548,  0.1560,  0.3511,  0.0162,  0.2921, -0.5813]])

# mu = 0.001  , 15 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.60, 0.59, 0.66]
w_source_trained = [[-0.4775,  0.6888, -0.1198,  0.7151, -0.1734,  1.0408]] 

# mu = 0.01, 15 epochs
source_acc = [1, 1, 1]
target_acc = [0.66, 0.65, 0.65]
w_source_trained = [[ 0.6250,  1.1280, -1.1299,  0.9362, -0.6652,  0.9637]] 

# mu = 0.1, 8 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.73, 0.76, 0.77]
w_source_trained = [[ 0.2208,  0.8593, -0.2424,  1.2031, -0.6159,  0.2616]]

# mu = 1, 8 epochs
source_acc = [0.96, 0.95, 0.95]
target_acc = [0.71, 0.71, 0.75]
w_source_trained = [[ 0.2349,  0.3647, -0.1661,  0.9425, -0.4218,  0.7059]]

# for mu = 10, accuracy falls below 95%

# %%
# a = tensor([[ 0.0134, -0.0910,  0.3160, -0.8696,  0.1324,  0.3434]])

# mu = 0.001  , 5 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.51, 0.50, 0.55]
w_source_trained = [[ 0.1565,  0.9204, -0.0946,  0.7939, -0.6091,  0.7343]]

# mu = 0.01
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.66, 0.66, 0.67]
w_source_trained = [[-0.0039,  0.7322, -0.1600,  0.8541, -1.3779,  0.2505]]

# mu = 0.1, 15 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.93, 0.91, 0.92]
w_source_trained = [[-0.2882,  0.7170,  0.0296,  1.4416, -0.5438,  0.0824]]

# mu = 1, 15 epochs
source_acc = [0.97, 0.97, 0.97]
target_acc = [0.94, 0.94, 0.94]
w_source_trained = [[-0.1304,  0.5285, -0.1702,  1.6559, -0.4881, -0.2931]]

# for mu = 10, accuracy falls below 95%

# %%
#a = tensor([[ 0.6083, -0.3120, -0.6793,  0.2148,  0.0410,  0.1530]])

# mu = 0.001, 5 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.55, 0.60, 0.64]
w_source_trained = [[-0.7677,  0.4094,  0.2514,  0.4826,  0.1933,  0.7787]]  

# mu = 0.01, 8 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.66, 0.61, 0.67]
w_source_trained = [[-0.0031,  0.5827, -0.0851,  0.6954, -0.3918,  0.0866]]

# mu = 0.1, 8 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.69, 0.70, 0.69]
w_source_trained = [[-0.9470,  1.4915,  0.6125,  0.6810, -0.2640, -0.4047]]

# mu = 1, 8 epochs
source_acc = [0.97, 0.97, 0.97]
target_acc = [0.73, 0.73, 0.73]
w_source_trained = [[-1.0258,  1.2641,  0.7887,  0.4299, -0.2424, -0.4422]]

# for mu = 10, accuracy falls below 95%

# %%
#a = [[ 0.5837, -0.3963,  0.4632,  0.1268, -0.1998,  0.4813]]

# mu = 0.001, 5 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.60, 0.56, 0.58]
w_source_trained = [[-0.3591,  0.6094,  0.1667,  0.5372, -0.1099,  0.1106]]  

# mu = 0.01, 8 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.62, 0.62, 0.54]
w_source_trained = [[ 0.0014,  0.8915, -0.1054,  0.6777, -0.4541, -0.1021]]

# mu = 0.1, 8 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.59, 0.57, 0.57]
w_source_trained = [[-0.2746,  0.8588, -0.0479,  0.5088, -0.5066, -0.0872]] 

# mu = 1, 8 epochs
source_acc = [0.96, 0.96, 0.95]
target_acc = [0.55, 0.55, 0.55]
w_source_trained = [[-0.6185,  1.5035, -0.2048,  0.4621,  0.2410, -0.7701]]

# for mu = 10, accuracy falls below 95%

# %%
#a = [[ 0.1665,  0.2515, -0.3178, -0.4967,  0.7481, -0.0417]]
# mu = 0.001, 5 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.65, 0.65, 0.52]
w_source_trained = [[-0.3227,  0.5323,  0.2871,  0.6838, -0.6364,  0.1632]]   

# mu = 0.01, 8 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.66, 0.56, 0.67]
w_source_trained = [[-0.7006,  0.6796,  0.4190,  0.7434, -0.3163,  0.4924]]

# mu = 0.1, 8 epochs
source_acc = [0.99, 0.99, 0.99]
target_acc = [0.87, 0.89, 0.88]
w_source_trained = [[-0.7063,  0.3584,  0.6435,  1.6803, -1.6303,  0.3471]] 

# mu = 1, 15 epochs
source_acc = [0.98, 0.98, 0.98]
target_acc = [0.88, 0.89, 0.89]
w_source_trained = [[-0.4663, -0.1366,  0.5699,  1.2206, -1.4612,  0.1269]] 

# for mu = 10, accuracy falls below 95%
