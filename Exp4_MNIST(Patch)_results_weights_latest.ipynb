# %% [markdown]
# ### 5*5 filter experiments - 3 * 3 patch dataset
# 1 classifier performance - []; mean accuracy =

# %%
#2 classifiers

# lambda = 1000

c1_source = [0.99, 0.99, 0.99]
c1_target = [0.61, 0.66, 0.64]

c2_source = [0.99, 0.99, 0.99]
c2_target = [0.59, 0.61, 0.63]

w1_best = [[-0.0946,  0.0319, -0.4058, -0.0553, -0.1509],
        [ 0.4275, -0.3814, -0.2585,  0.4354, -0.1026],
        [-0.0358,  0.0850,  0.0903, -0.4340, -0.0293],
        [ 0.2269,  0.4369,  0.0664,  0.0908,  0.0140],
        [ 0.0039, -0.1530,  0.2718, -0.0412,  0.3385]]

w2_best = [[ 0.1104, -0.0908,  0.2862,  0.1434,  0.3410],
        [ 0.3066, -0.2876, -0.4562,  0.1853, -0.3662],
        [ 0.0960,  0.2350,  0.4126,  0.0305, -0.3026],
        [ 0.0269,  0.0540,  0.1146,  0.0868, -0.2223],
        [-0.2338, -0.2935, -0.0460, -0.3860,  0.1934]]

# %%
#3 classifiers

# lambda = 1000

c1_source = [0.99, 0.99, 0.99]
c1_target = [0.62, 0.67, 0.63]

c2_source = [0.99, 0.99, 0.99]
c2_target = [0.58, 0.57, 0.62]

c3_source = [0.99, 0.99, 0.99]
c3_target = [0.51, 0.51, 0.59]

w1_best =  [[ 0.2603, -0.1214,  0.2663,  0.1736, -0.2448],
        [-0.0836,  0.3334, -0.0214,  0.1772,  0.3900],
        [ 0.3496, -0.2636, -0.2640,  0.1497,  0.1490],
        [ 0.3067, -0.0786,  0.1568, -0.0173, -0.0953],
        [-0.3397, -0.4216, -0.0463, -0.0843,  0.4477]]

w2_best = [[-0.3795,  0.4719,  0.0188, -0.4316, -0.4650],
        [-0.3596,  0.0055, -0.1792, -0.4277,  0.1511],
        [-0.0370, -0.1015, -0.2235, -0.1026, -0.4205],
        [ 0.0650,  0.1656,  0.2250,  0.3825,  0.1532],
        [ 0.0219,  0.4734, -0.2394,  0.0573,  0.1668]]

w3_best = [[-0.2512,  0.1353, -0.2351,  0.0973, -0.1302],
        [-0.2225, -0.1094, -0.1017,  0.0876,  0.2097],
        [ 0.0683, -0.2388,  0.3058, -0.0034, -0.2191],
        [ 0.0670,  0.1915, -0.3071,  0.0301, -0.1291],
        [ 0.1773,  0.1889,  0.0996, -0.0185, -0.1618]]

# %%
#4 classifiers 

# lambda = 100; 3 epochs

c1_source = [0.99, 0.99, 0.99]
c1_target = [0.75, 0.68, 0.69]

c2_source = [0.99, 0.99, 0.99]
c2_target = [0.58, 0.58, 0.57]

c3_source = [0.99, 0.99, 0.99]
c3_target = [0.57, 0.50, 0.53]

c4_source = [0.99, 0.99, 0.99]
c4_target = [0.50, 0.49, 0.52]

w1_best = [[ 1.6385e-03, -6.4188e-02,  2.9892e-01, -1.3673e-01,  2.2203e-01],
        [ 1.6437e-01,  1.1000e-01,  2.1103e-01, -1.7225e-01,  9.4002e-02],
        [-2.8163e-02,  8.2287e-02,  5.8955e-02,  1.0655e-01, -9.4503e-03],
        [ 2.3734e-01, -9.7326e-03,  9.0922e-05,  3.3079e-04, -8.5104e-02],
        [ 3.3902e-02,  1.7655e-03, -9.6314e-02,  4.4122e-02, -9.6336e-02]]
w2_best =[[-0.3408, -0.1482, -0.2570,  0.0429,  0.4561],
        [ 0.2706, -0.3726, -0.0570,  0.2716,  0.2498],
        [ 0.1287, -0.0670,  0.0666,  0.1791, -0.1601],
        [-0.0389,  0.3180, -0.1544, -0.1043, -0.1217],
        [-0.2490, -0.1301, -0.1538, -0.0029, -0.0429]]
w3_best = [[ 0.2949,  0.5944, -0.5779,  0.0635, -0.4644],
        [-0.2806,  0.0341, -0.1069,  0.2322, -0.1975],
        [ 0.2960, -0.3697, -0.3819, -0.4842, -0.2454],
        [-0.4383, -0.4232,  0.0295,  0.4419, -0.0955],
        [ 0.0586,  0.4315,  0.3823, -0.1611, -0.1155]]
w4_best = [[ 0.0053,  0.4549, -0.0745, -0.1389,  0.0106],
        [-0.4706,  0.2293, -0.1726, -0.4484, -0.1534],
        [-0.3099, -0.3030, -0.2289, -0.3936, -0.2791],
        [ 0.0193,  0.3278,  0.2176, -0.0678, -0.2038],
        [ 0.0357,  0.0163, -0.1141, -0.1612,  0.0221]]

# %%
#5 classifiers 

# lambda = 10000; 3 epochs

c1_source = [0.99, 0.99, 0.99]
c1_target = [0.73, 0.79, 0.65]

c2_source = [0.99, 0.99, 0.99]
c2_target = [0.66, 0.66, 0.63]

c3_source = [0.99, 0.99, 0.99]
c3_target = [0.63, 0.63, 0.63]

c4_source = [0.99, 0.99, 0.99]
c4_target = [0.59, 0.59, 0.62]

c5_source = [0.99, 0.99, 0.99]
c5_target = [0.51, 0.51, 0.52]

w1_best =[[-0.4065,  0.3881,  0.1025,  0.4817, -0.1142],
        [ 0.1007, -0.1952, -0.3607, -0.2361,  0.2678],
        [-0.0330,  0.2593, -0.1973,  0.0638,  0.0443],
        [ 0.3908,  0.1141, -0.1568,  0.1754,  0.1255],
        [-0.4165,  0.2844,  0.0095,  0.3799,  0.1120]]

w2_best = [[ 0.2711,  0.4365,  0.1842,  0.1901, -0.2160],
        [-0.4974,  0.3516,  0.4261,  0.0103,  0.1815],
        [ 0.2921, -0.2095,  0.3356,  0.1320,  0.3607],
        [-0.1886, -0.3682, -0.1417, -0.4206, -0.2294],
        [ 0.2227,  0.2301, -0.5262, -0.2045,  0.2169]]

w3_best = [[-0.1948, -0.1600, -0.0121, -0.1588,  0.1069],
        [ 0.0711,  0.1729, -0.0899,  0.0138, -0.1818],
        [-0.2554,  0.2879, -0.1008,  0.0435, -0.0366],
        [-0.1195, -0.0093,  0.0338,  0.1893,  0.0528],
        [ 0.1025, -0.0659,  0.2037, -0.0556, -0.0185]]

w4_best = [[ 0.2363, -0.3752, -0.4299, -0.0682, -0.1963],
        [-0.2785, -0.3671, -0.3891,  0.2142, -0.1793],
        [ 0.2251, -0.1023, -0.3890,  0.0245, -0.2094],
        [ 0.0143, -0.1635,  0.1142, -0.2681,  0.3797],
        [ 0.0746, -0.2868,  0.1047,  0.3227,  0.1386]]

w5_best = [[-0.2421, -0.0801,  0.0591,  0.1455, -0.1837],
        [ 0.1997, -0.0978, -0.2355,  0.0137,  0.0315],
        [-0.3509, -0.1544, -0.1931, -0.1488, -0.0664],
        [ 0.1283,  0.2201,  0.0908,  0.2024, -0.3450],
        [-0.1359,  0.3504, -0.3440,  0.0496, -0.2010]]

# %%
#6 classifiers 

# lambda = 10000; 3 epochs

c1_source = [0.99, 0.99, 0.99]
c1_target = [0.77, 0.71, 0.77]

c2_source = [0.99, 0.99, 0.99]
c2_target = [0.59, 0.62, 0.63]

c3_source = [0.99, 0.99, 0.99]
c3_target = [0.58, 0.59, 0.63]

c4_source = [0.99, 0.99, 0.99]
c4_target = [0.57, 0.56, 0.57]

c5_source = [0.99, 0.99, 0.99]
c5_target = [0.52, 0.55, 0.56]

c6_source = [0.99, 0.99, 0.99]
c6_target = [0.50, 0.50, 0.51]

w1_best = [[-0.1046,  0.1955, -0.2136, -0.1972,  0.4603],
        [-0.0186,  0.4712,  0.0895,  0.1397, -0.1944],
        [ 0.4008,  0.0200,  0.0583,  0.1744,  0.2127],
        [ 0.4361,  0.1048, -0.2479,  0.3281,  0.1012],
        [-0.4398, -0.3875,  0.0061,  0.5159,  0.1784]]

w2_best = [[ 0.2159, -0.2823, -0.3465, -0.5772,  0.3099],
        [ 0.1990,  0.1477,  0.0652, -0.0386, -0.1138],
        [-0.4071, -0.3181, -0.3748,  0.0311,  0.3416],
        [-0.2043,  0.2371, -0.3083, -0.1462, -0.1913],
        [ 0.0368, -0.1040,  0.2630,  0.1374, -0.2316]]

w3_best =  [[ 0.1233, -0.3009,  0.0240,  0.1769, -0.1247],
        [ 0.0214, -0.0799, -0.0372, -0.0229,  0.0122],
        [ 0.0365, -0.0571,  0.1064, -0.1495, -0.2196],
        [ 0.0303,  0.0832, -0.1007,  0.1385, -0.0062],
        [-0.0369,  0.1019, -0.0175, -0.0218,  0.1134]]

w4_best =  [[-0.4239,  0.2856,  0.0551, -0.5596,  0.0648],
        [ 0.2182, -0.1874,  0.0039, -0.1435, -0.0952],
        [ 0.4240,  0.3034, -0.1512,  0.3535, -0.4281],
        [ 0.0727, -0.3191,  0.1913, -0.3709, -0.1083],
        [-0.0478,  0.2821,  0.0735,  0.2108, -0.1308]]

w5_best = [[-0.2410, -0.1328, -0.1420,  0.4480,  0.4099],
        [-0.0963,  0.0232,  0.0015, -0.1614,  0.2312],
        [ 0.3109, -0.3257, -0.1903, -0.4041,  0.2096],
        [-0.1169,  0.2711, -0.1966,  0.1534, -0.1105],
        [-0.0446, -0.3329, -0.2017,  0.1184, -0.1847]]

w6_best = [[ 0.0233, -0.1357, -0.1732, -0.1902, -0.2232],
        [-0.1282,  0.0474, -0.1864, -0.1886,  0.2671],
        [ 0.1826,  0.0766,  0.1791, -0.1338,  0.0215],
        [-0.1252,  0.0058,  0.0227,  0.0741,  0.2871],
        [ 0.0977, -0.2040, -0.0740, -0.3071,  0.0919]]

# %% [markdown]
# ### 3*3 filter experiments - 3 * 3 patch dataset
# 1 classifier performance - [0.73, 0.68, 0.70]; mean accuracy =

# %%
#2 classifiers

# lambda = 100, 3 epochs, lr 0.0001

c1_source = [1]
c1_target = [0.68, 0.64, 0.65]

c2_source = [1]
c2_target = [0.65, 0.61, 0.61]

w1_best = [[-0.0186, -0.1920,  0.0448],
        [ 0.4309, -0.0071, -0.7903],
        [-0.1932,  0.8210,  0.6730]]

w2_best = [[-0.1559,  0.1432, -0.0194],
        [-0.2600,  0.0094,  0.4795],
        [ 0.0628, -0.4989, -0.4113]]

# %%
#3 classifiers

# lambda = 100, 3 epochs, lr 0.0001

c1_source = [0.99, 0.99, 0.99]
c1_target = [0.76, 0.73, 0.83]

c2_source = [0.99, 0.99, 0.99]
c2_target = [0.68, 0.70, 0.63]

c3_source = [0.99, 0.99, 0.99]
c3_target = [0.65, 0.56, 0.56]

w1_best =  [[-0.3610,  0.2816,  0.1793],
        [ 0.1656,  0.1330, -0.3847],
        [ 0.4741,  0.1236,  0.3243]]

w2_best = [[-0.1777,  0.0181, -0.6502],
        [ 0.2258, -0.5224,  0.2100],
        [-0.0915, -0.4784,  0.1552]]

w3_best = [[-0.6439,  0.2676,  0.4553],
        [-0.2370, -0.3823,  0.1625],
        [-0.5530, -0.3236,  0.0534]]

# %%
#4 classifiers 

# lambda = 100; 4 epochs

c1_source = [1, 1, 1]
c1_target = [0.84, 0.72, 0.82]

c2_source = [0.99, 0.99, 0.99]
c2_target = [0.71, 0.72, 0.73]

c3_source = [0.99, 0.99, 0.99]
c3_target = [0.70, 0.66, 0.72]

c4_source = [0.99, 0.99, 0.99]
c4_target = [0.69, 0.63, 0.69]

w1_best = [[ 0.1991,  0.4669,  0.1902],
        [ 0.2805,  0.2125,  0.2307],
        [-0.1677, -0.0320,  0.1087]]

w2_best = [[ 0.4407, -0.1260,  0.0334],
        [-0.2343, -0.5811,  0.2014],
        [ 0.2314,  0.7520,  0.1456]]

w3_best = [[ 0.1505,  0.3960,  0.2529],
        [-0.1932,  0.3770, -0.6734],
        [ 0.3461, -0.0341,  0.0442]]

w4_best = [[-0.1986, -0.5985, -0.3421],
        [-0.5223, -0.3264, -0.5010],
        [ 0.1573, -0.1931,  0.4973]]

# %%
#5 classifiers 

# lambda = 100; 4 epochs

c1_source = [1, 1, 0.99]
c1_target = [0.78, 0.78, 0.84]

c2_source = [1, 1, 0.99]
c2_target = [0.72, 0.74, 0.73]

c3_source = [1, 0.99, 1]
c3_target = [0.71, 0.66, 0.69]

c4_source = [0.99, 0.99, 0.99]
c4_target = [0.70, 0.63, 0.68]

c5_source = [1, 1, 0.99]
c5_target = [0.67, 0.62, 0.65]

w1_best = [[ 0.1789, -0.2537, -0.2942],
        [-0.1804,  0.5869,  0.4221],
        [ 0.6345,  0.5337,  0.5304]]

w2_best = [[ 0.2785,  0.4669,  0.0979],
        [-0.1405, -0.1438, -0.0367],
        [ 0.1726,  0.6619, -0.5242]]

w3_best = [[-0.4962, -0.2727, -0.2849],
        [ 0.0085, -0.2738,  0.2518],
        [ 0.1574, -0.1344,  0.1174]]

w4_best = [[-0.5210, -0.2893,  0.2037],
        [-0.3070,  0.5529, -0.3936],
        [ 0.2958,  0.2826, -0.7234]]

w5_best = [[ 0.2061,  0.0128,  0.2156],
        [ 0.5560, -0.2923, -0.1310],
        [-0.2247,  0.2871, -0.0012]]

# %%
#6 classifiers 

# lambda = 10000; 3 epochs

c1_source = [0.99, 0.99, 0.99]
c1_target = [0.81, 0.79, 0.81]

c2_source = [0.99, 0.99, 0.99]
c2_target = [0.78, 0.74, 0.72]

c3_source = [0.99, 0.99, 0.99]
c3_target = [0.72, 0.72, 0.70]

c4_source = [0.99, 0.99, 0.99]
c4_target = [0.67, 0.67, 0.67]

c5_source = [0.99, 0.99, 0.99]
c5_target = [0.64, 0.60, 0.64]

c6_source = [0.99, 0.99, 0.99]
c6_target = [0.61, 0.55, 0.61]

w1_best = [[ 0.3014,  0.5347,  0.3094],
        [ 0.3988, -0.1159, -0.1079],
        [-0.1395,  0.0927,  0.3120]]

w2_best = [[ 0.1619,  0.2536,  0.0352],
        [ 0.1179, -0.1457,  0.4372],
        [ 0.1643, -0.2203,  0.1736]]

w3_best = [[ 0.3825, -0.2140, -0.2068],
        [-0.3494,  0.6575, -0.2683],
        [-0.3189,  0.1453, -0.2281]] 

w4_best = [[-0.6071, -0.2180, -0.0696],
        [-0.2432, -0.4199,  0.0223],
        [ 0.6155,  0.1196, -0.0578]]

w5_best = [[-0.6315, -0.4129,  0.5171],
        [-0.2958,  0.5227, -0.2123],
        [-0.2651,  0.1547, -0.6461]]

w6_best = [[ 0.2078, -0.1968, -0.5725],
        [ 0.1046, -0.4186, -0.2603],
        [-0.1809, -0.2360,  0.1673]]

# %% [markdown]
# ### 7*7 filter experiments - 3 * 3 patch dataset
# 1 classifier performance - [0.69, 0.63, 0.64]; mean accuracy =

# %%
#2 classifiers

# lambda = 100, 3 epochs, lr 0.0001

c1_source = [0.97, 0.99]
c1_target = [0.76, 0.69, 0.76]

c2_source = [0.98, 0.99]
c2_target = [0.70, 0.63, 0.74]

w1_best =[[-0.0461,  0.1671, -0.2129,  0.1792, -0.0034,  0.1608,  0.0369],
        [ 0.0064, -0.1209,  0.0052,  0.1783, -0.1036,  0.1479, -0.0666],
        [ 0.0645, -0.1344,  0.0696,  0.0471, -0.0686,  0.0545, -0.0309],
        [ 0.0527,  0.1377, -0.1353,  0.0860,  0.1498,  0.1818,  0.1101],
        [ 0.0548, -0.0588,  0.0956, -0.0734,  0.0684, -0.0904, -0.1791],
        [ 0.1298, -0.0593, -0.0134,  0.0058,  0.0007, -0.1627,  0.0230],
        [-0.1730,  0.1439, -0.1807, -0.0413, -0.0125,  0.1518, -0.1825]]

w2_best = [[ 0.0258, -0.2982,  0.3158, -0.2913,  0.0071, -0.2459, -0.0932],
        [-0.0377,  0.1728, -0.0206, -0.2930,  0.1700, -0.2571,  0.1248],
        [-0.1298,  0.2096, -0.1302, -0.0875,  0.1148,  0.0692,  0.0932],
        [-0.1060, -0.2357,  0.2126, -0.1501, -0.2531, -0.3029, -0.1868],
        [-0.1037,  0.0867, -0.1667,  0.1126, -0.1242,  0.1411,  0.2898],
        [-0.2226,  0.1017,  0.0141, -0.0708, -0.0099,  0.2579, -0.0115],
        [ 0.2671, -0.2450,  0.2817,  0.0575, -0.0616, -0.2581,  0.2904]]

# %%
#3 classifiers

# lambda = 100, 3 epochs, lr 0.0001

c1_source = [0.96, 0.99, 0.93]
c1_target = [0.75, 0.78, 0.85]

c2_source = [0.99, 0.99, 0.98]
c2_target = [0.63, 0.64, 0.72]

c3_source = [0.99, 0.95, 0.99]
c3_target = [0.57, 0.53, 0.57]

w1_best = [[-0.2050,  0.3664,  0.1478, -0.3023,  0.0389, -0.2915,  0.0042],
        [ 0.2420,  0.2294,  0.1613,  0.3206,  0.0832,  0.0919, -0.1677],
        [-0.0793, -0.1369,  0.3422,  0.2305, -0.0022,  0.0229,  0.0951],
        [ 0.0652,  0.0725,  0.3138,  0.0265,  0.1195,  0.2728, -0.1184],
        [-0.3076, -0.2709,  0.2589, -0.2628, -0.1631,  0.1366, -0.1339],
        [ 0.0169,  0.0263, -0.1754,  0.0237,  0.1484, -0.0147,  0.0842],
        [ 0.2397,  0.3498,  0.0446,  0.1284,  0.0984,  0.2270,  0.0092]]

w2_best = [[ 0.2773, -0.0419,  0.0232,  0.0428,  0.0702,  0.0464,  0.0777],
        [-0.0329, -0.0871, -0.1300, -0.0331, -0.0555, -0.0329,  0.1418],
        [ 0.0258, -0.0511, -0.0973, -0.0255, -0.0135,  0.0064, -0.1774],
        [ 0.0140,  0.0825, -0.0679, -0.2486, -0.0686, -0.0192,  0.0537],
        [ 0.0982, -0.0267,  0.0412,  0.2568,  0.2066, -0.0113, -0.0950],
        [-0.0767, -0.0725,  0.2002, -0.0210, -0.0179, -0.0371, -0.0644],
        [-0.1526, -0.0880, -0.0847,  0.0914, -0.0629,  0.0176, -0.0889]]
w3_best = [[ 0.0038,  0.2713, -0.0594, -0.2337,  0.0190, -0.1143,  0.1130],
        [ 0.2358, -0.0563,  0.0277,  0.1712,  0.0095, -0.0107,  0.0417],
        [ 0.0170,  0.0075, -0.0304,  0.0207, -0.2331,  0.0659, -0.0595],
        [-0.0511,  0.2607, -0.0819,  0.0477, -0.1242, -0.0666,  0.0438],
        [ 0.1086, -0.0873, -0.0532, -0.1737, -0.0494,  0.0056,  0.0017],
        [ 0.0978, -0.0438, -0.0234, -0.0013,  0.1113, -0.0177,  0.0626],
        [-0.0076, -0.0811,  0.1652,  0.2147, -0.1001,  0.0131, -0.0662]]

# %%
#4 classifiers 

# lambda = 1000; 3 epochs

c1_source = [0.84, 0.98, 0.94]
c1_target = [0.84, 0.83, 0.85]

c2_source = [0.96, 0.99, 0.98]
c2_target = [0.72, 0.71, 0.70]

c3_source = [0.98, 0.98, 0.99]
c3_target = [0.71, 0.66, 0.68]

c4_source = [0.94, 0.99, 0.99]
c4_target = [0.52, 0.64, 0.61]

w1_best = [[ 0.0919, -0.1897,  0.0465, -0.2089,  0.1046,  0.3186,  0.1554],
        [-0.1809, -0.0671,  0.1587, -0.3880, -0.1543, -0.2395,  0.0510],
        [-0.0197, -0.3653,  0.0822,  0.0619,  0.0681,  0.0206,  0.0200],
        [-0.3398,  0.2205,  0.0993,  0.3451,  0.1188,  0.3243,  0.2981],
        [-0.0295, -0.0620, -0.1355, -0.2703,  0.2517,  0.2158, -0.0773],
        [-0.2059,  0.0841,  0.3102,  0.3530,  0.3123, -0.3197, -0.2179],
        [ 0.3202,  0.0941, -0.1588, -0.1913,  0.0952,  0.2656, -0.0745]]
w2_best = [[ 0.2958,  0.0816,  0.1364, -0.0992,  0.1358, -0.0601,  0.0194],
        [ 0.0556,  0.0876, -0.0067, -0.1271,  0.0746,  0.0364, -0.1999],
        [-0.2611, -0.2308, -0.0240,  0.2377,  0.2373,  0.1612,  0.0943],
        [-0.0892,  0.1333, -0.0708,  0.0741, -0.0445,  0.2186, -0.1974],
        [-0.0119,  0.1879,  0.1770,  0.0783, -0.1038, -0.1297,  0.0798],
        [ 0.2781, -0.0267, -0.0473,  0.0722, -0.0849,  0.0738,  0.0492],
        [-0.1094,  0.0882, -0.1542,  0.1531, -0.1157,  0.0398, -0.1778]]
w3_best =[[ 0.0039, -0.2770, -0.0333,  0.0086, -0.2966, -0.0606, -0.0255],
        [ 0.3092,  0.0677,  0.0536, -0.0661, -0.1043,  0.0384,  0.0459],
        [ 0.1144,  0.0714, -0.2425, -0.2313, -0.2907, -0.1665, -0.1072],
        [ 0.0937, -0.0793,  0.3189, -0.0693,  0.0870,  0.0308,  0.0972],
        [-0.0633, -0.1355, -0.0455,  0.0024,  0.2768, -0.1532, -0.0868],
        [-0.2684, -0.2181, -0.0460,  0.0300, -0.0930, -0.0839, -0.3107],
        [ 0.1030, -0.2115, -0.1264, -0.0753, -0.0997, -0.1553,  0.0905]]
w4_best = [[ 0.2085, -0.2219, -0.1292,  0.0443,  0.2148,  0.0606, -0.2848],
        [-0.0336, -0.3566,  0.0058,  0.0522,  0.0377, -0.0512,  0.0406],
        [-0.1876, -0.2347,  0.1327, -0.2219,  0.0459, -0.1151,  0.0599],
        [-0.0546, -0.2284, -0.0565,  0.0189, -0.0080,  0.1015,  0.0414],
        [ 0.1797,  0.1901,  0.2718,  0.0162,  0.1253,  0.0550,  0.0745],
        [ 0.1049, -0.2748,  0.1574, -0.1827, -0.0522, -0.2127,  0.2790],
        [-0.0726, -0.0522,  0.0850,  0.0734, -0.2761, -0.0619, -0.2962]]

# %%
#5 classifiers 

# lambda = 100; 2 epochs

c1_source = [0.83, 0.89, 0.99]
c1_target = [0.83, 0.86, 0.78]

c2_source = [0.96, 0.99, 0.98]
c2_target = [0.80, 0.73, 0.69]

c3_source = [0.94, 0.99, 0.96]
c3_target = [0.77, 0.73, 0.69] 

c4_source = [0.98, 0.99, 0.99]
c4_target = [0.68, 0.65, 0.65]

c5_source = [0.98, 0.99, 0.99]
c5_target = [0.68, 0.58, 0.54]

w1_best = [[-0.0867, -0.0175,  0.2335, -0.0714,  0.0813, -0.0648,  0.0414],
        [-0.0316, -0.0927, -0.0622,  0.0790,  0.2389, -0.0119,  0.1817],
        [-0.0403, -0.0608,  0.1408,  0.1894,  0.0665,  0.1554,  0.0648],
        [ 0.0095, -0.1428,  0.1489,  0.1120,  0.1257, -0.0129, -0.0869],
        [ 0.0856, -0.2151,  0.0031,  0.0145,  0.1126, -0.1800,  0.1509],
        [-0.0820,  0.1688,  0.0210,  0.0195, -0.1409,  0.0541,  0.0718],
        [ 0.1355, -0.1315,  0.0109,  0.2239,  0.1169,  0.1287, -0.0307]]

w2_best = [[ 0.0912, -0.0522,  0.2232, -0.1673, -0.1907,  0.0328, -0.3301],
        [ 0.3399, -0.0598, -0.2261, -0.1549, -0.1572,  0.0650,  0.1079],
        [-0.2072,  0.1162,  0.1925, -0.0729, -0.0597,  0.1143,  0.1176],
        [ 0.0602, -0.2117, -0.0307,  0.0223, -0.0215, -0.0312, -0.1427],
        [-0.2298,  0.1409,  0.0870, -0.2351, -0.0397,  0.0340,  0.1123],
        [-0.1414, -0.1319,  0.0080, -0.2660,  0.0922, -0.2909, -0.0242],
        [-0.0291, -0.1875,  0.2378, -0.1715,  0.0840, -0.0968, -0.0860]]

w3_best = [[ 0.2091,  0.1278, -0.0203,  0.0968, -0.0082, -0.3728,  0.3106],
        [-0.2783, -0.1493,  0.3024, -0.0803, -0.1010,  0.0976,  0.0255],
        [-0.1007,  0.1155, -0.2855, -0.0838, -0.1946, -0.0651, -0.2052],
        [ 0.0980,  0.1511,  0.0372,  0.1017,  0.0252, -0.1072, -0.3260],
        [-0.2116,  0.0536,  0.2788, -0.2246, -0.1453, -0.0473, -0.1403],
        [ 0.0235, -0.1168, -0.0718, -0.1476, -0.0393,  0.1619, -0.1158],
        [-0.0678,  0.3328, -0.3149,  0.2942,  0.3180,  0.2420, -0.2214]]
w4_best = [[-0.1750, -0.0380, -0.2491,  0.0363,  0.1395,  0.1210,  0.1678],
        [ 0.1186,  0.0010, -0.0308,  0.1621,  0.0615, -0.0960,  0.0647],
        [ 0.2037, -0.1128,  0.0692,  0.0259,  0.1907, -0.0527, -0.0606],
        [-0.2094,  0.0821,  0.0865, -0.0749, -0.1173,  0.1588,  0.0759],
        [-0.1220,  0.0885, -0.2436,  0.1385,  0.0140,  0.0252, -0.2057],
        [ 0.0411, -0.0637,  0.0988, -0.0646,  0.0016, -0.0587,  0.1801],
        [ 0.0976,  0.1599, -0.0918, -0.2051, -0.0335, -0.0903,  0.0491]]

w5_best = [[-0.1750, -0.0380, -0.2491,  0.0363,  0.1395,  0.1210,  0.1678],
        [ 0.1186,  0.0010, -0.0308,  0.1621,  0.0615, -0.0960,  0.0647],
        [ 0.2037, -0.1128,  0.0692,  0.0259,  0.1907, -0.0527, -0.0606],
        [-0.2094,  0.0821,  0.0865, -0.0749, -0.1173,  0.1588,  0.0759],
        [-0.1220,  0.0885, -0.2436,  0.1385,  0.0140,  0.0252, -0.2057],
        [ 0.0411, -0.0637,  0.0988, -0.0646,  0.0016, -0.0587,  0.1801],
        [ 0.0976,  0.1599, -0.0918, -0.2051, -0.0335, -0.0903,  0.0491]]

# %%
#6 classifiers 

# lambda = 100; 2 epochs

c1_source = [0.88, 0.87, 0.88]
c1_target = [0.86, 0.84, 0.85]

c2_source = [0.92, 0.99, 0.98]
c2_target = [0.82, 0.77, 0.72]

c3_source = [0.96, 0.99, 0.97]
c3_target = [0.79, 0.72, 0.71]

c4_source = [0.99, 0.99, 0.98]
c4_target = [0.77, 0.68, 0.69]

c5_source = [0.99, 0.99, 0.98]
c5_target = [0.59, 0.60, 0.68]

c6_source = [0.99, 0.99, 0.99]
c6_target = [0.52, 0.60, 0.55]

w1_best = [[-0.1138,  0.0723,  0.1368,  0.2118, -0.0276, -0.2866, -0.1119],
        [ 0.1674, -0.2174, -0.1148,  0.1993, -0.3017,  0.2391, -0.1095],
        [ 0.0957,  0.2659,  0.0476,  0.2483,  0.1531, -0.1275,  0.1016],
        [ 0.1642,  0.2856, -0.0863,  0.1260, -0.2237, -0.0009,  0.2267],
        [ 0.3187, -0.0447,  0.1765, -0.0536,  0.0150,  0.1152,  0.0377],
        [-0.1420,  0.1156,  0.1615, -0.0409, -0.0897, -0.0045, -0.0932],
        [ 0.0747, -0.1480,  0.0397,  0.0004, -0.1526, -0.2388,  0.1408]]

w2_best = [[-2.4767e-01,  2.0940e-02,  4.9145e-02,  3.5942e-02,  1.1617e-01,
         -8.7801e-02,  9.1561e-02],
        [ 5.0637e-03,  1.2822e-01,  1.0018e-01, -2.1913e-02, -8.5115e-03,
          2.8981e-03,  8.2882e-02],
        [ 2.3564e-02,  5.5614e-02,  1.7629e-02, -1.0319e-01,  7.1849e-02,
          6.5131e-02, -1.0893e-01],
        [-2.2669e-02, -1.6372e-01, -6.8784e-02,  1.5113e-01, -1.0642e-01,
         -1.1723e-01, -5.9439e-02],
        [ 3.2556e-02, -1.3267e-01,  4.8509e-02,  8.0386e-02, -2.3419e-01,
         -7.3971e-02,  7.8704e-02],
        [-8.5190e-02, -1.9732e-01, -1.6329e-01,  4.7586e-02, -8.6023e-02,
          1.7167e-02, -4.0449e-02],
        [ 2.8354e-02, -4.7472e-02,  1.4349e-02,  4.0522e-05, -7.2588e-02,
          7.5973e-02, -2.3501e-02]]

w3_best = [[-1.5373e-01, -2.0124e-01, -1.8460e-02,  3.7289e-02,  1.2849e-01,
          2.1318e-01,  2.1330e-01],
        [ 7.8653e-02, -2.0611e-02,  2.4974e-02, -6.8467e-02,  2.7698e-01,
         -1.3735e-01,  4.9557e-02],
        [-8.6053e-02,  2.8200e-01,  5.1762e-02, -5.8724e-02,  2.1226e-01,
         -5.1034e-02,  5.1308e-02],
        [-1.2802e-01, -2.8223e-01,  1.4940e-01, -9.9584e-02,  1.6014e-01,
          3.3250e-03, -2.8933e-01],
        [ 1.5845e-01,  5.8617e-02, -7.5333e-03, -7.6941e-02,  1.4960e-01,
         -4.7662e-02,  1.0013e-01],
        [ 2.5885e-02,  6.8041e-02, -8.9200e-03,  9.0977e-03,  1.7295e-01,
          2.7666e-02,  5.4231e-02],
        [ 1.5743e-01, -1.9156e-02, -3.6289e-02,  2.0859e-02, -7.4638e-04,
          1.3305e-01, -7.6362e-05]]

w4_best = [[ 0.1308, -0.2569, -0.2398,  0.1511, -0.3183, -0.0135, -0.3425],
        [-0.2072, -0.2664, -0.1894, -0.3217,  0.0902, -0.0541, -0.1188],
        [-0.0628, -0.3440,  0.1194, -0.2384, -0.2571,  0.1134, -0.1488],
        [-0.0508,  0.2650, -0.0416, -0.1425,  0.0621,  0.0274,  0.1982],
        [-0.2068, -0.0736,  0.2200, -0.1091,  0.0570,  0.0850, -0.0442],
        [ 0.1004,  0.0093,  0.1759,  0.0763,  0.2633, -0.0227,  0.1060],
        [ 0.0613, -0.2095,  0.0331, -0.3269,  0.2990,  0.0149, -0.1841]]

w5_best = [[ 0.0309,  0.0708,  0.2634,  0.2444,  0.1341, -0.0710,  0.0841],
        [ 0.3202,  0.0380,  0.0956, -0.2557,  0.2295, -0.0928, -0.2458],
        [ 0.0574,  0.0180, -0.0241,  0.1588,  0.0120,  0.1212, -0.0456],
        [-0.0893, -0.1084, -0.0583, -0.0275,  0.0330, -0.1524,  0.0306],
        [-0.0938,  0.1272, -0.0239,  0.2152,  0.1030,  0.1619, -0.1301],
        [ 0.0754, -0.2011, -0.1756, -0.2371, -0.2429,  0.1842, -0.1287],
        [ 0.1600, -0.1098,  0.1571,  0.2294,  0.1584, -0.1353,  0.2181]]

w6_best = [[ 0.1399,  0.2629, -0.1356, -0.2709,  0.1839,  0.0842, -0.0401],
        [ 0.0917,  0.3267, -0.1652, -0.2753,  0.3132, -0.2885,  0.1752],
        [ 0.0399,  0.1739,  0.0829, -0.2370,  0.0117, -0.0816,  0.1420],
        [-0.0838,  0.0474,  0.0817, -0.1517, -0.1484,  0.1406, -0.3043],
        [-0.0488,  0.0316, -0.1495,  0.2743,  0.0037,  0.0501, -0.0739],
        [ 0.2678, -0.2064, -0.1819, -0.1999, -0.0372,  0.0324,  0.0526],
        [ 0.2672,  0.0657, -0.0389,  0.3049,  0.0595, -0.0863,  0.0720]]
